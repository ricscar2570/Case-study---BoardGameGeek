# %%
games_data = []  # Assicurati che la lista sia inizializzata

import time
import requests
import xml.etree.ElementTree as ET

# %%
games_data = []  # Assicurati che la lista sia inizializzata

def get_data_with_backoff(game_id, max_retries=5):
    url = f"https://boardgamegeek.com/xmlapi2/thing?id={game_id}&stats=1"
    delay = 2  # Ritardo iniziale in secondi
    for i in range(max_retries):
        try:
            response = requests.get(url)
            response.raise_for_status()
            time.sleep(1)  # Pausa per evitare di sovraccaricare l'API

            # Parsing XML
            root = ET.fromstring(response.content)
            item = root.find("item")
            
            # Verifica presenza di dati
            if item is not None:
                # Usa il metodo `find` in modo sicuro con un controllo per ogni elemento
                year_published = item.find("yearpublished")
                year_published = int(year_published.get("value", 0)) if year_published is not None else None
                
                # Filtra solo i giochi dal 2022 in poi
                if year_published and year_published >= 2022:
                    game_info = {
                        "BGGId": game_id,
                        "Name": item.find("name").get("value") if item.find("name") is not None else "N/A",
                        "YearPublished": year_published,
                        "GameWeight": float(item.find("statistics/ratings/averageweight").get("value", 0)) if item.find("statistics/ratings/averageweight") is not None else 0,
                        "AvgRating": float(item.find("statistics/ratings/average").get("value", 0)) if item.find("statistics/ratings/average") is not None else 0,
                        "BayesAvgRating": float(item.find("statistics/ratings/bayesaverage").get("value", 0)) if item.find("statistics/ratings/bayesaverage") is not None else 0,
                        "NumOwned": int(item.find("statistics/ratings/owned").get("value", 0)) if item.find("statistics/ratings/owned") is not None else 0,
                        "NumComments": int(item.find("statistics/ratings/numcomments").get("value", 0)) if item.find("statistics/ratings/numcomments") is not None else 0,
                        "NumUserRatings": int(item.find("statistics/ratings/usersrated").get("value", 0)) if item.find("statistics/ratings/usersrated") is not None else 0,
                        "MinPlayers": int(item.find("minplayers").get("value", 1)) if item.find("minplayers") is not None else 1,
                        "MaxPlayers": int(item.find("maxplayers").get("value", 1)) if item.find("maxplayers") is not None else 1,
                        "MinPlaytime": int(item.find("minplaytime").get("value", 0)) if item.find("minplaytime") is not None else 0,
                        "MaxPlaytime": int(item.find("maxplaytime").get("value", 0)) if item.find("maxplaytime") is not None else 0,
                        "AgeRec": int(item.find("minage").get("value", 0)) if item.find("minage") is not None else 0,
                        "Description": item.find("description").text.strip() if item.find("description") is not None else ""
                    }
                    games_data.append(game_info)
                    print(f"Recuperati dati per il gioco {game_id}")
                    return game_info  # Esce dalla funzione se il recupero ha successo

        except requests.exceptions.HTTPError as e:
            if response.status_code == 429:
                print(f"Errore 429: Tentativo {i + 1} - Attendo {delay} secondi prima di riprovare...")
                time.sleep(delay)
                delay *= 2  # Raddoppia il ritardo
            else:
                print(f"Errore nel recuperare i dati per il gioco {game_id}: {e}")
                break
        except Exception as e:
            print(f"Errore generico per il gioco {game_id}: {e}")
            break

    return None  # Ritorna None se non riesce dopo max_retries tentativi

# %%
# Esegui per ogni ID di gioco
game_ids = range(354623,400000)  # La lista di ID di giochi che vuoi recuperare
for game_id in game_ids:
    get_data_with_backoff(game_id)

# Stampa i dati raccolti o esegui altre operazioni
print(f"Totale giochi recuperati: {len(games_data)}")
# Out:
# Recuperati dati per il gioco 354628
# Recuperati dati per il gioco 354629
# Recuperati dati per il gioco 354632
# Recuperati dati per il gioco 354656
# Recuperati dati per il gioco 354660
# Recuperati dati per il gioco 354664
# Recuperati dati per il gioco 354665
# Recuperati dati per il gioco 354669
# Recuperati dati per il gioco 354672
# Recuperati dati per il gioco 354675
# Recuperati dati per il gioco 354676
# Recuperati dati per il gioco 354677
# Recuperati dati per il gioco 354679
# Recuperati dati per il gioco 354680
# Recuperati dati per il gioco 354682
# Recuperati dati per il gioco 354693
# Recuperati dati per il gioco 354698
# Recuperati dati per il gioco 354703
# Recuperati dati per il gioco 354704
# Recuperati dati per il gioco 354706
# Recuperati dati per il gioco 354707
# Recuperati dati per il gioco 354710
# Recuperati dati per il gioco 354714
# Recuperati dati per il gioco 354715
# Recuperati dati per il gioco 354718
# Recuperati dati per il gioco 354722
# Recuperati dati per il gioco 354724
# Recuperati dati per il gioco 354725
# Recuperati dati per il gioco 354726
# Recuperati dati per il gioco 354727
# Recuperati dati per il gioco 354729
# Recuperati dati per il gioco 354730
# Recuperati dati per il gioco 354737
# Recuperati dati per il gioco 354743
# Recuperati dati per il gioco 354744
# Recuperati dati per il gioco 354745
# Recuperati dati per il gioco 354746
# Recuperati dati per il gioco 354747
# Recuperati dati per il gioco 354748
# Recuperati dati per il gioco 354749
# Recuperati dati per il gioco 354750
# Recuperati dati per il gioco 354751
# Recuperati dati per il gioco 354752
# Recuperati dati per il gioco 354753
# Recuperati dati per il gioco 354754
# Recuperati dati per il gioco 354755
# Recuperati dati per il gioco 354756
# Recuperati dati per il gioco 354757
# Recuperati dati per il gioco 354758
# Recuperati dati per il gioco 354759
# Recuperati dati per il gioco 354760
# Recuperati dati per il gioco 354765
# Recuperati dati per il gioco 354766
# Recuperati dati per il gioco 354767
# Recuperati dati per il gioco 354768
# Recuperati dati per il gioco 354773
# Recuperati dati per il gioco 354774
# Recuperati dati per il gioco 354775
# Recuperati dati per il gioco 354776
# Recuperati dati per il gioco 354777
# Recuperati dati per il gioco 354778
# Recuperati dati per il gioco 354779
# Recuperati dati per il gioco 354787
# Recuperati dati per il gioco 354789
# Recuperati dati per il gioco 354790
# Recuperati dati per il gioco 354794
# Recuperati dati per il gioco 354795
# Recuperati dati per il gioco 354796
# Recuperati dati per il gioco 354797
# Recuperati dati per il gioco 354798
# Recuperati dati per il gioco 354799
# Recuperati dati per il gioco 354800
# Recuperati dati per il gioco 354802
# Recuperati dati per il gioco 354803
# Recuperati dati per il gioco 354804
# Recuperati dati per il gioco 354805
# Recuperati dati per il gioco 354806
# Recuperati dati per il gioco 354809
# Recuperati dati per il gioco 354810
# Recuperati dati per il gioco 354811
# Recuperati dati per il gioco 354812
# Recuperati dati per il gioco 354813
# Errore 429: Tentativo 1 - Attendo 2 secondi prima di riprovare...
# Recuperati dati per il gioco 354814
# Errore 429: Tentativo 1 - Attendo 2 secondi prima di riprovare...
# Recuperati dati per il gioco 354815
# Errore 429: Tentativo 1 - Attendo 2 secondi prima di riprovare...
# Recuperati dati per il gioco 354816
# Errore 429: Tentativo 1 - Attendo 2 secondi prima di riprovare...
# Errore 429: Tentativo 3 - Attendo 4 secondi prima di riprovare...
# Recuperati dati per il gioco 354823
# Recuperati dati per il gioco 354824
# Errore 429: Tentativo 2 - Attendo 2 secondi prima di riprovare...
# Recuperati dati per il gioco 354842
# Recuperati dati per il gioco 354843
# Recuperati dati per il gioco 354844
# Recuperati dati per il gioco 354845
# Recuperati dati per il gioco 354846
# Recuperati dati per il gioco 354847
# Errore 429: Tentativo 2 - Attendo 2 secondi prima di riprovare...
# Recuperati dati per il gioco 354852
# Recuperati dati per il gioco 354853
# Recuperati dati per il gioco 354854
# Recuperati dati per il gioco 354855
# Recuperati dati per il gioco 354856
# Errore 429: Tentativo 1 - Attendo 2 secondi prima di riprovare...
# Recuperati dati per il gioco 354857
# Errore 429: Tentativo 1 - Attendo 2 secondi prima di riprovare...
# Recuperati dati per il gioco 354858
# Errore 429: Tentativo 1 - Attendo 2 secondi prima di riprovare...
# Recuperati dati per il gioco 354859
# Errore 429: Tentativo 1 - Attendo 2 secondi prima di riprovare...
# Recuperati dati per il gioco 354866
# Recuperati dati per il gioco 354873
# Recuperati dati per il gioco 354874
# Recuperati dati per il gioco 354876
# Recuperati dati per il gioco 354877
# Recuperati dati per il gioco 354878
# Errore 429: Tentativo 1 - Attendo 2 secondi prima di riprovare...
# Errore 429: Tentativo 3 - Attendo 4 secondi prima di riprovare...
# Recuperati dati per il gioco 354880
# Recuperati dati per il gioco 354881
# Recuperati dati per il gioco 354882
# Recuperati dati per il gioco 354884
# Recuperati dati per il gioco 354885
# Recuperati dati per il gioco 354886
# Errore 429: Tentativo 1 - Attendo 2 secondi prima di riprovare...
# Recuperati dati per il gioco 354887
# Errore 429: Tentativo 1 - Attendo 2 secondi prima di riprovare...
# Errore 429: Tentativo 2 - Attendo 2 secondi prima di riprovare...
# Recuperati dati per il gioco 354892
# Recuperati dati per il gioco 354893
# Recuperati dati per il gioco 354894
# Recuperati dati per il gioco 354895
# Recuperati dati per il gioco 354896
# Errore 429: Tentativo 1 - Attendo 2 secondi prima di riprovare...
# Errore 429: Tentativo 3 - Attendo 4 secondi prima di riprovare...
# Recuperati dati per il gioco 354898
# Recuperati dati per il gioco 354899
# Recuperati dati per il gioco 354903
# Recuperati dati per il gioco 354912
# Recuperati dati per il gioco 354913
# Recuperati dati per il gioco 354914
# Errore 429: Tentativo 1 - Attendo 2 secondi prima di riprovare...
# Recuperati dati per il gioco 354915
# Errore 429: Tentativo 1 - Attendo 2 secondi prima di riprovare...
# Recuperati dati per il gioco 354916
# Errore 429: Tentativo 1 - Attendo 2 secondi prima di riprovare...
# Recuperati dati per il gioco 354917
# Errore 429: Tentativo 1 - Attendo 2 secondi prima di riprovare...
# Recuperati dati per il gioco 354918
# Errore 429: Tentativo 1 - Attendo 2 secondi prima di riprovare...
# Recuperati dati per il gioco 354922
# Recuperati dati per il gioco 354923
# Errore 429: Tentativo 2 - Attendo 2 secondi prima di riprovare...
# Recuperati dati per il gioco 354932
# Recuperati dati per il gioco 354934
# Recuperati dati per il gioco 354939
# Recuperati dati per il gioco 354940
# Recuperati dati per il gioco 354941
# Recuperati dati per il gioco 354942
# Errore 429: Tentativo 2 - Attendo 2 secondi prima di riprovare...
# Recuperati dati per il gioco 354944
# Recuperati dati per il gioco 354945
# Recuperati dati per il gioco 354946
# Errore 429: Tentativo 1 - Attendo 2 secondi prima di riprovare...
# Recuperati dati per il gioco 354947
# Errore 429: Tentativo 1 - Attendo 2 secondi prima di riprovare...
# Recuperati dati per il gioco 354948
# Errore 429: Tentativo 1 - Attendo 2 secondi prima di riprovare...
# Errore 429: Tentativo 3 - Attendo 4 secondi prima di riprovare...
# Recuperati dati per il gioco 354957
# Recuperati dati per il gioco 354975
# Recuperati dati per il gioco 354979
# Recuperati dati per il gioco 354980
# Recuperati dati per il gioco 354981
# Recuperati dati per il gioco 354982
# Recuperati dati per il gioco 354983
# Recuperati dati per il gioco 354995
# Recuperati dati per il gioco 355010
# Recuperati dati per il gioco 355017
# Recuperati dati per il gioco 355027
# Recuperati dati per il gioco 355030
# Recuperati dati per il gioco 355035
# Recuperati dati per il gioco 355036
# Recuperati dati per il gioco 355037
# Recuperati dati per il gioco 355039
# Recuperati dati per il gioco 355050
# Recuperati dati per il gioco 355059
# Recuperati dati per il gioco 355060
# Recuperati dati per il gioco 355063
# Recuperati dati per il gioco 355065
# Recuperati dati per il gioco 355066
# Recuperati dati per il gioco 355067
# Recuperati dati per il gioco 355071
# Recuperati dati per il gioco 355080
# Recuperati dati per il gioco 355081
# Recuperati dati per il gioco 355083
# Recuperati dati per il gioco 355087
# Recuperati dati per il gioco 355093
# Recuperati dati per il gioco 355097
# Recuperati dati per il gioco 355098
# Recuperati dati per il gioco 355099
# Recuperati dati per il gioco 355100
# Recuperati dati per il gioco 355101
# Recuperati dati per il gioco 355103
# Recuperati dati per il gioco 355104
# Recuperati dati per il gioco 355105
# Recuperati dati per il gioco 355106
# Recuperati dati per il gioco 355109
# Recuperati dati per il gioco 355113
# Recuperati dati per il gioco 355114
# Recuperati dati per il gioco 355115
# Recuperati dati per il gioco 355116
# Recuperati dati per il gioco 355117
# Recuperati dati per il gioco 355118
# Recuperati dati per il gioco 355119
# Recuperati dati per il gioco 355120
# Recuperati dati per il gioco 355122
# Recuperati dati per il gioco 355125
# Recuperati dati per il gioco 355126
# Recuperati dati per il gioco 355128
# Recuperati dati per il gioco 355129
# Errore 429: Tentativo 2 - Attendo 2 secondi prima di riprovare...
# Recuperati dati per il gioco 355132
# Recuperati dati per il gioco 355134
# Recuperati dati per il gioco 355135
# Recuperati dati per il gioco 355141
# Recuperati dati per il gioco 355145
# Recuperati dati per il gioco 355160
# Recuperati dati per il gioco 355162
# Recuperati dati per il gioco 355164
# Recuperati dati per il gioco 355165
# Recuperati dati per il gioco 355166
# Recuperati dati per il gioco 355167
# Recuperati dati per il gioco 355168
# Errore 429: Tentativo 1 - Attendo 2 secondi prima di riprovare...
# Recuperati dati per il gioco 355169
# Errore 429: Tentativo 1 - Attendo 2 secondi prima di riprovare...
# Recuperati dati per il gioco 355170
# Errore 429: Tentativo 1 - Attendo 2 secondi prima di riprovare...
# Recuperati dati per il gioco 355171
# Errore 429: Tentativo 1 - Attendo 2 secondi prima di riprovare...
# Recuperati dati per il gioco 355172
# Errore 429: Tentativo 1 - Attendo 2 secondi prima di riprovare...
# Recuperati dati per il gioco 355173
# Errore 429: Tentativo 1 - Attendo 2 secondi prima di riprovare...
# Recuperati dati per il gioco 355179
# Errore 429: Tentativo 2 - Attendo 2 secondi prima di riprovare...
# Errore 429: Tentativo 2 - Attendo 2 secondi prima di riprovare...
# Recuperati dati per il gioco 355184
# Recuperati dati per il gioco 355185
# Recuperati dati per il gioco 355186
# Recuperati dati per il gioco 355187
# Recuperati dati per il gioco 355188
# Errore 429: Tentativo 1 - Attendo 2 secondi prima di riprovare...
# Recuperati dati per il gioco 355189
# Errore 429: Tentativo 1 - Attendo 2 secondi prima di riprovare...
# Recuperati dati per il gioco 355190
# Errore 429: Tentativo 1 - Attendo 2 secondi prima di riprovare...
# Recuperati dati per il gioco 355191
# Errore 429: Tentativo 1 - Attendo 2 secondi prima di riprovare...
# Errore 429: Tentativo 3 - Attendo 4 secondi prima di riprovare...
# Recuperati dati per il gioco 355193
# Recuperati dati per il gioco 355197
# Recuperati dati per il gioco 355200
# Recuperati dati per il gioco 355201
# Recuperati dati per il gioco 355205
# Recuperati dati per il gioco 355212
# Recuperati dati per il gioco 355220
# Recuperati dati per il gioco 355222
# Recuperati dati per il gioco 355224
# Recuperati dati per il gioco 355234
# Recuperati dati per il gioco 355244
# Recuperati dati per il gioco 355246
# Recuperati dati per il gioco 355247
# Recuperati dati per il gioco 355249
# Recuperati dati per il gioco 355256
# Recuperati dati per il gioco 355259
# Recuperati dati per il gioco 355260
# Recuperati dati per il gioco 355261
# Recuperati dati per il gioco 355264
# Recuperati dati per il gioco 355271
# Recuperati dati per il gioco 355274
# Recuperati dati per il gioco 355276
# Recuperati dati per il gioco 355277
# Recuperati dati per il gioco 355292
# Recuperati dati per il gioco 355293
# Recuperati dati per il gioco 355294
# Recuperati dati per il gioco 355318
# Recuperati dati per il gioco 355326
# Recuperati dati per il gioco 355327
# Recuperati dati per il gioco 355328
# Recuperati dati per il gioco 355333
# Recuperati dati per il gioco 355346
# Recuperati dati per il gioco 355349
# Recuperati dati per il gioco 355353
# Recuperati dati per il gioco 355355
# Recuperati dati per il gioco 355375
# Recuperati dati per il gioco 355379
# Recuperati dati per il gioco 355383
# Recuperati dati per il gioco 355406
# Recuperati dati per il gioco 355407
# Recuperati dati per il gioco 355416
# Recuperati dati per il gioco 355419
# Recuperati dati per il gioco 355433
# Recuperati dati per il gioco 355435
# Recuperati dati per il gioco 355437
# Recuperati dati per il gioco 355441
# Recuperati dati per il gioco 355442
# Recuperati dati per il gioco 355443
# Recuperati dati per il gioco 355444
# Recuperati dati per il gioco 355445
# Recuperati dati per il gioco 355446
# Recuperati dati per il gioco 355447
# Recuperati dati per il gioco 355448
# Recuperati dati per il gioco 355449
# Recuperati dati per il gioco 355450
# Recuperati dati per il gioco 355451
# Recuperati dati per il gioco 355452
# Recuperati dati per il gioco 355456
# Recuperati dati per il gioco 355457
# Recuperati dati per il gioco 355458
# Recuperati dati per il gioco 355459
# Recuperati dati per il gioco 355467
# Recuperati dati per il gioco 355468
# Recuperati dati per il gioco 355471
# Recuperati dati per il gioco 355475
# Recuperati dati per il gioco 355481
# Recuperati dati per il gioco 355483
# Recuperati dati per il gioco 355491
# Recuperati dati per il gioco 355492
# Recuperati dati per il gioco 355493
# Recuperati dati per il gioco 355494
# Recuperati dati per il gioco 355495
# Errore 429: Tentativo 1 - Attendo 2 secondi prima di riprovare...
# Recuperati dati per il gioco 355497
# Errore 429: Tentativo 1 - Attendo 2 secondi prima di riprovare...
# Recuperati dati per il gioco 355501
# Errore 429: Tentativo 1 - Attendo 2 secondi prima di riprovare...
# Recuperati dati per il gioco 355502
# Errore 429: Tentativo 1 - Attendo 2 secondi prima di riprovare...
# Recuperati dati per il gioco 355503
# Errore 429: Tentativo 1 - Attendo 2 secondi prima di riprovare...
# Recuperati dati per il gioco 355504
# Errore 429: Tentativo 1 - Attendo 2 secondi prima di riprovare...
# Recuperati dati per il gioco 355505
# Errore 429: Tentativo 1 - Attendo 2 secondi prima di riprovare...
# Recuperati dati per il gioco 355506
# Errore 429: Tentativo 1 - Attendo 2 secondi prima di riprovare...
# Recuperati dati per il gioco 355507
# Errore 429: Tentativo 1 - Attendo 2 secondi prima di riprovare...
# Recuperati dati per il gioco 355508
# Errore 429: Tentativo 1 - Attendo 2 secondi prima di riprovare...
# Recuperati dati per il gioco 355509
# Errore 429: Tentativo 1 - Attendo 2 secondi prima di riprovare...
# Recuperati dati per il gioco 355510
# Errore 429: Tentativo 1 - Attendo 2 secondi prima di riprovare...
# Recuperati dati per il gioco 355511
# Errore 429: Tentativo 1 - Attendo 2 secondi prima di riprovare...
# Recuperati dati per il gioco 355513
# Errore 429: Tentativo 1 - Attendo 2 secondi prima di riprovare...
# Errore 429: Tentativo 3 - Attendo 4 secondi prima di riprovare...
# Recuperati dati per il gioco 355516
# Recuperati dati per il gioco 355521
# Recuperati dati per il gioco 355563
# Recuperati dati per il gioco 355564
# Recuperati dati per il gioco 355567
# Recuperati dati per il gioco 355569
# Recuperati dati per il gioco 355570
# Recuperati dati per il gioco 355571
# Recuperati dati per il gioco 355576
# Recuperati dati per il gioco 355578
# Recuperati dati per il gioco 355590
# Recuperati dati per il gioco 355593
# Recuperati dati per il gioco 355594
# Recuperati dati per il gioco 355595
# Recuperati dati per il gioco 355596
# Recuperati dati per il gioco 355597
# Errore 429: Tentativo 1 - Attendo 2 secondi prima di riprovare...
# Recuperati dati per il gioco 355598
# Errore 429: Tentativo 1 - Attendo 2 secondi prima di riprovare...
# Recuperati dati per il gioco 355604
# Recuperati dati per il gioco 355609
# Recuperati dati per il gioco 355610
# Recuperati dati per il gioco 355611
# Errore 429: Tentativo 1 - Attendo 2 secondi prima di riprovare...
# Recuperati dati per il gioco 355612
# Errore 429: Tentativo 1 - Attendo 2 secondi prima di riprovare...
# Recuperati dati per il gioco 355613
# Errore 429: Tentativo 1 - Attendo 2 secondi prima di riprovare...
# Recuperati dati per il gioco 355614
# Errore 429: Tentativo 1 - Attendo 2 secondi prima di riprovare...
# Recuperati dati per il gioco 355615
# Errore 429: Tentativo 1 - Attendo 2 secondi prima di riprovare...
# Recuperati dati per il gioco 355616
# Errore 429: Tentativo 1 - Attendo 2 secondi prima di riprovare...
# Recuperati dati per il gioco 355617
# Errore 429: Tentativo 1 - Attendo 2 secondi prima di riprovare...
# Recuperati dati per il gioco 355618
# Errore 429: Tentativo 1 - Attendo 2 secondi prima di riprovare...
# Recuperati dati per il gioco 355619
# Errore 429: Tentativo 1 - Attendo 2 secondi prima di riprovare...
# Errore 429: Tentativo 3 - Attendo 4 secondi prima di riprovare...
# Recuperati dati per il gioco 355622
# Recuperati dati per il gioco 355623
# Recuperati dati per il gioco 355629
# Recuperati dati per il gioco 355632
# Recuperati dati per il gioco 355636
# Errore 429: Tentativo 2 - Attendo 2 secondi prima di riprovare...
# Errore 429: Tentativo 2 - Attendo 2 secondi prima di riprovare...
# Recuperati dati per il gioco 355639
# Recuperati dati per il gioco 355640
# Errore 429: Tentativo 2 - Attendo 2 secondi prima di riprovare...
# Errore 429: Tentativo 2 - Attendo 2 secondi prima di riprovare...
# Errore 429: Tentativo 2 - Attendo 2 secondi prima di riprovare...
# Errore 429: Tentativo 2 - Attendo 2 secondi prima di riprovare...
# Recuperati dati per il gioco 355648
# Recuperati dati per il gioco 355649
# Recuperati dati per il gioco 355651
# Errore 429: Tentativo 1 - Attendo 2 secondi prima di riprovare...
# Errore 429: Tentativo 3 - Attendo 4 secondi prima di riprovare...
# Recuperati dati per il gioco 355655
# Recuperati dati per il gioco 355660
# Recuperati dati per il gioco 355661
# Recuperati dati per il gioco 355662
# Recuperati dati per il gioco 355667
# Recuperati dati per il gioco 355670
# Errore 429: Tentativo 1 - Attendo 2 secondi prima di riprovare...
# Errore 429: Tentativo 3 - Attendo 4 secondi prima di riprovare...
# Recuperati dati per il gioco 355677
# Recuperati dati per il gioco 355686
# Recuperati dati per il gioco 355691
# Errore 429: Tentativo 2 - Attendo 2 secondi prima di riprovare...
# Recuperati dati per il gioco 355700
# Recuperati dati per il gioco 355701
# Recuperati dati per il gioco 355702
# Errore 429: Tentativo 1 - Attendo 2 secondi prima di riprovare...
# Recuperati dati per il gioco 355703
# Errore 429: Tentativo 1 - Attendo 2 secondi prima di riprovare...
# Recuperati dati per il gioco 355704
# Errore 429: Tentativo 1 - Attendo 2 secondi prima di riprovare...
# Errore 429: Tentativo 3 - Attendo 4 secondi prima di riprovare...
# Recuperati dati per il gioco 355722
# Recuperati dati per il gioco 355730
# Recuperati dati per il gioco 355733
# Recuperati dati per il gioco 355735
# Recuperati dati per il gioco 355736
# Recuperati dati per il gioco 355737
# Recuperati dati per il gioco 355753
# Recuperati dati per il gioco 355754
# Recuperati dati per il gioco 355755
# Recuperati dati per il gioco 355756
# Recuperati dati per il gioco 355757
# Recuperati dati per il gioco 355758
# Recuperati dati per il gioco 355759
# Recuperati dati per il gioco 355760
# Recuperati dati per il gioco 355761
# Recuperati dati per il gioco 355762
# Recuperati dati per il gioco 355763
# Recuperati dati per il gioco 355764
# Recuperati dati per il gioco 355765
# Recuperati dati per il gioco 355766
# Recuperati dati per il gioco 355767
# Errore 429: Tentativo 1 - Attendo 2 secondi prima di riprovare...
# Recuperati dati per il gioco 355768
# Errore 429: Tentativo 1 - Attendo 2 secondi prima di riprovare...
# Recuperati dati per il gioco 355769
# Errore 429: Tentativo 1 - Attendo 2 secondi prima di riprovare...
# Errore 429: Tentativo 3 - Attendo 4 secondi prima di riprovare...
# Recuperati dati per il gioco 355771
# Recuperati dati per il gioco 355772
# Recuperati dati per il gioco 355773
# Errore 429: Tentativo 1 - Attendo 2 secondi prima di riprovare...
# Recuperati dati per il gioco 355774
# Errore 429: Tentativo 1 - Attendo 2 secondi prima di riprovare...
# Recuperati dati per il gioco 355775
# Errore 429: Tentativo 1 - Attendo 2 secondi prima di riprovare...
# Errore 429: Tentativo 3 - Attendo 4 secondi prima di riprovare...
# Recuperati dati per il gioco 355786
# Recuperati dati per il gioco 355787
# Recuperati dati per il gioco 355788
# Recuperati dati per il gioco 355792
# Recuperati dati per il gioco 355793
# Recuperati dati per il gioco 355794
# Recuperati dati per il gioco 355800
# Recuperati dati per il gioco 355801
# Recuperati dati per il gioco 355804
# Errore 429: Tentativo 1 - Attendo 2 secondi prima di riprovare...
# Errore 429: Tentativo 3 - Attendo 4 secondi prima di riprovare...
# Recuperati dati per il gioco 355817
# Recuperati dati per il gioco 355824
# Recuperati dati per il gioco 355829
# Recuperati dati per il gioco 355844
# Recuperati dati per il gioco 355845
# Recuperati dati per il gioco 355847
# Recuperati dati per il gioco 355850
# Recuperati dati per il gioco 355852
# Recuperati dati per il gioco 355853
# Recuperati dati per il gioco 355865
# Recuperati dati per il gioco 355866
# Recuperati dati per il gioco 355867
# Recuperati dati per il gioco 355868
# Recuperati dati per il gioco 355869
# Errore 429: Tentativo 1 - Attendo 2 secondi prima di riprovare...
# Recuperati dati per il gioco 355870
# Errore 429: Tentativo 1 - Attendo 2 secondi prima di riprovare...
# Recuperati dati per il gioco 355871
# Errore 429: Tentativo 1 - Attendo 2 secondi prima di riprovare...
# Recuperati dati per il gioco 355872
# Errore 429: Tentativo 1 - Attendo 2 secondi prima di riprovare...
# Recuperati dati per il gioco 355873
# Errore 429: Tentativo 1 - Attendo 2 secondi prima di riprovare...
# Recuperati dati per il gioco 355874
# Errore 429: Tentativo 1 - Attendo 2 secondi prima di riprovare...
# Errore 429: Tentativo 3 - Attendo 4 secondi prima di riprovare...
# Recuperati dati per il gioco 355876
# Recuperati dati per il gioco 355877
# Errore 429: Tentativo 2 - Attendo 2 secondi prima di riprovare...
# Recuperati dati per il gioco 355879
# Errore 429: Tentativo 2 - Attendo 2 secondi prima di riprovare...
# Recuperati dati per il gioco 355881
# Errore 429: Tentativo 2 - Attendo 2 secondi prima di riprovare...
# Errore 429: Tentativo 2 - Attendo 2 secondi prima di riprovare...
# Errore 429: Tentativo 2 - Attendo 2 secondi prima di riprovare...
# Recuperati dati per il gioco 355887
# Errore 429: Tentativo 1 - Attendo 2 secondi prima di riprovare...
# Recuperati dati per il gioco 355888
# Errore 429: Tentativo 1 - Attendo 2 secondi prima di riprovare...
# Errore 429: Tentativo 3 - Attendo 4 secondi prima di riprovare...
# Recuperati dati per il gioco 355890
# Recuperati dati per il gioco 355891
# Recuperati dati per il gioco 355892
# Recuperati dati per il gioco 355894
# Recuperati dati per il gioco 355895
# Errore 429: Tentativo 1 - Attendo 2 secondi prima di riprovare...
# Recuperati dati per il gioco 355896
# Errore 429: Tentativo 1 - Attendo 2 secondi prima di riprovare...
# Errore 429: Tentativo 3 - Attendo 4 secondi prima di riprovare...
# Recuperati dati per il gioco 355899
# Recuperati dati per il gioco 355902
# Errore 429: Tentativo 2 - Attendo 2 secondi prima di riprovare...
# Errore 429: Tentativo 2 - Attendo 2 secondi prima di riprovare...
# Errore 429: Tentativo 2 - Attendo 2 secondi prima di riprovare...
# Errore 429: Tentativo 2 - Attendo 2 secondi prima di riprovare...
# Recuperati dati per il gioco 355910
# Recuperati dati per il gioco 355911
# Recuperati dati per il gioco 355913
# Errore 429: Tentativo 1 - Attendo 2 secondi prima di riprovare...
# Recuperati dati per il gioco 355914
# Errore 429: Tentativo 1 - Attendo 2 secondi prima di riprovare...
# Errore 429: Tentativo 3 - Attendo 4 secondi prima di riprovare...
# Recuperati dati per il gioco 355916
# Recuperati dati per il gioco 355917
# Errore 429: Tentativo 2 - Attendo 2 secondi prima di riprovare...
# Errore 429: Tentativo 2 - Attendo 2 secondi prima di riprovare...
# Recuperati dati per il gioco 355922
# Recuperati dati per il gioco 355923
# Errore 429: Tentativo 1 - Attendo 2 secondi prima di riprovare...
# Recuperati dati per il gioco 355927
# Errore 429: Tentativo 2 - Attendo 2 secondi prima di riprovare...
# Recuperati dati per il gioco 355933
# Errore 429: Tentativo 1 - Attendo 2 secondi prima di riprovare...
# Errore 429: Tentativo 3 - Attendo 4 secondi prima di riprovare...
# Recuperati dati per il gioco 355940
# Recuperati dati per il gioco 355946
# Recuperati dati per il gioco 355951
# Recuperati dati per il gioco 355952
# Recuperati dati per il gioco 355953
# Errore 429: Tentativo 1 - Attendo 2 secondi prima di riprovare...
# Errore 429: Tentativo 1 - Attendo 2 secondi prima di riprovare...
# Errore 429: Tentativo 2 - Attendo 2 secondi prima di riprovare...
# Recuperati dati per il gioco 355957
# Errore 429: Tentativo 1 - Attendo 2 secondi prima di riprovare...
# Recuperati dati per il gioco 355958
# Errore 429: Tentativo 1 - Attendo 2 secondi prima di riprovare...
# Errore 429: Tentativo 3 - Attendo 4 secondi prima di riprovare...
# Recuperati dati per il gioco 355960
# Recuperati dati per il gioco 355963
# Recuperati dati per il gioco 355964
# Recuperati dati per il gioco 355965
# Errore 429: Tentativo 1 - Attendo 2 secondi prima di riprovare...
# Recuperati dati per il gioco 355966
# Errore 429: Tentativo 1 - Attendo 2 secondi prima di riprovare...
# Recuperati dati per il gioco 355967
# Errore 429: Tentativo 1 - Attendo 2 secondi prima di riprovare...
# Errore 429: Tentativo 3 - Attendo 4 secondi prima di riprovare...
# Recuperati dati per il gioco 355973
# Recuperati dati per il gioco 355974
# Recuperati dati per il gioco 355975
# Errore 429: Tentativo 1 - Attendo 2 secondi prima di riprovare...
# Recuperati dati per il gioco 355976
# Errore 429: Tentativo 1 - Attendo 2 secondi prima di riprovare...
# Recuperati dati per il gioco 355977
# Errore 429: Tentativo 1 - Attendo 2 secondi prima di riprovare...
# Recuperati dati per il gioco 355978
# Errore 429: Tentativo 1 - Attendo 2 secondi prima di riprovare...
# Recuperati dati per il gioco 355979
# Errore 429: Tentativo 1 - Attendo 2 secondi prima di riprovare...
# Errore 429: Tentativo 3 - Attendo 4 secondi prima di riprovare...
# Recuperati dati per il gioco 355982
# Recuperati dati per il gioco 355983
# Recuperati dati per il gioco 355984
# Recuperati dati per il gioco 355986
# Recuperati dati per il gioco 355989
# Recuperati dati per il gioco 355996
# Recuperati dati per il gioco 355997
# Recuperati dati per il gioco 356002
# Recuperati dati per il gioco 356015
# Recuperati dati per il gioco 356016
# Recuperati dati per il gioco 356017
# Recuperati dati per il gioco 356018
# Recuperati dati per il gioco 356019
# Errore 429: Tentativo 1 - Attendo 2 secondi prima di riprovare...
# Recuperati dati per il gioco 356020
# Errore 429: Tentativo 1 - Attendo 2 secondi prima di riprovare...
# Recuperati dati per il gioco 356021
# Errore 429: Tentativo 1 - Attendo 2 secondi prima di riprovare...
# Recuperati dati per il gioco 356025
# Recuperati dati per il gioco 356026
# Recuperati dati per il gioco 356027
# Errore 429: Tentativo 1 - Attendo 2 secondi prima di riprovare...
# Recuperati dati per il gioco 356028
# Errore 429: Tentativo 1 - Attendo 2 secondi prima di riprovare...
# Recuperati dati per il gioco 356029
# Errore 429: Tentativo 1 - Attendo 2 secondi prima di riprovare...
# Recuperati dati per il gioco 356030
# Errore 429: Tentativo 1 - Attendo 2 secondi prima di riprovare...
# Recuperati dati per il gioco 356031
# Errore 429: Tentativo 1 - Attendo 2 secondi prima di riprovare...
# Errore 429: Tentativo 3 - Attendo 4 secondi prima di riprovare...
# Recuperati dati per il gioco 356033
# Recuperati dati per il gioco 356035
# Recuperati dati per il gioco 356036
# Recuperati dati per il gioco 356037
# Recuperati dati per il gioco 356039
# Recuperati dati per il gioco 356040
# Errore 429: Tentativo 1 - Attendo 2 secondi prima di riprovare...
# Recuperati dati per il gioco 356041
# Errore 429: Tentativo 1 - Attendo 2 secondi prima di riprovare...
# Recuperati dati per il gioco 356042
# Errore 429: Tentativo 1 - Attendo 2 secondi prima di riprovare...
# Recuperati dati per il gioco 356043
# Errore 429: Tentativo 1 - Attendo 2 secondi prima di riprovare...
# Recuperati dati per il gioco 356044
# Errore 429: Tentativo 1 - Attendo 2 secondi prima di riprovare...
# Recuperati dati per il gioco 356045
# Errore 429: Tentativo 1 - Attendo 2 secondi prima di riprovare...
# Recuperati dati per il gioco 356046
# Errore 429: Tentativo 1 - Attendo 2 secondi prima di riprovare...
# Errore 429: Tentativo 2 - Attendo 2 secondi prima di riprovare...
# Recuperati dati per il gioco 356049
# Errore 429: Tentativo 2 - Attendo 2 secondi prima di riprovare...
# Recuperati dati per il gioco 356052
# Errore 429: Tentativo 1 - Attendo 2 secondi prima di riprovare...
# Errore 429: Tentativo 3 - Attendo 4 secondi prima di riprovare...
# Recuperati dati per il gioco 356054
# Recuperati dati per il gioco 356058
# Recuperati dati per il gioco 356060
# Errore 429: Tentativo 1 - Attendo 2 secondi prima di riprovare...
# Recuperati dati per il gioco 356061
# Errore 429: Tentativo 1 - Attendo 2 secondi prima di riprovare...
# Errore 429: Tentativo 3 - Attendo 4 secondi prima di riprovare...
# Recuperati dati per il gioco 356063
# Recuperati dati per il gioco 356072
# Recuperati dati per il gioco 356073
# Recuperati dati per il gioco 356074
# Recuperati dati per il gioco 356075
# Recuperati dati per il gioco 356077
# Errore 429: Tentativo 1 - Attendo 2 secondi prima di riprovare...
# Errore 429: Tentativo 3 - Attendo 4 secondi prima di riprovare...
# Recuperati dati per il gioco 356080
# Recuperati dati per il gioco 356082
# Recuperati dati per il gioco 356084
# Recuperati dati per il gioco 356085
# Recuperati dati per il gioco 356086
# Recuperati dati per il gioco 356095
# Recuperati dati per il gioco 356096
# Recuperati dati per il gioco 356097
# Recuperati dati per il gioco 356102
# Recuperati dati per il gioco 356103
# Recuperati dati per il gioco 356104
# Recuperati dati per il gioco 356107
# Recuperati dati per il gioco 356110
# Recuperati dati per il gioco 356111
# Recuperati dati per il gioco 356112
# Recuperati dati per il gioco 356114
# Errore 429: Tentativo 1 - Attendo 2 secondi prima di riprovare...
# Recuperati dati per il gioco 356121
# Recuperati dati per il gioco 356123
# Errore 429: Tentativo 1 - Attendo 2 secondi prima di riprovare...
# Recuperati dati per il gioco 356124
# Errore 429: Tentativo 1 - Attendo 2 secondi prima di riprovare...
# Errore 429: Tentativo 3 - Attendo 4 secondi prima di riprovare...
# Recuperati dati per il gioco 356126
# Recuperati dati per il gioco 356127
# Recuperati dati per il gioco 356128
# Recuperati dati per il gioco 356129
# Recuperati dati per il gioco 356132
# Recuperati dati per il gioco 356133
# Recuperati dati per il gioco 356134
# Errore 429: Tentativo 1 - Attendo 2 secondi prima di riprovare...
# Recuperati dati per il gioco 356135
# Errore 429: Tentativo 1 - Attendo 2 secondi prima di riprovare...
# Recuperati dati per il gioco 356140
# Errore 429: Tentativo 2 - Attendo 2 secondi prima di riprovare...
# Errore 429: Tentativo 2 - Attendo 2 secondi prima di riprovare...
# Errore 429: Tentativo 2 - Attendo 2 secondi prima di riprovare...
# Recuperati dati per il gioco 356159
# Recuperati dati per il gioco 356160
# Recuperati dati per il gioco 356161
# Recuperati dati per il gioco 356162
# Recuperati dati per il gioco 356163
# Recuperati dati per il gioco 356164
# Recuperati dati per il gioco 356165
# Errore 429: Tentativo 1 - Attendo 2 secondi prima di riprovare...
# Errore 429: Tentativo 3 - Attendo 4 secondi prima di riprovare...
# Recuperati dati per il gioco 356169
# Recuperati dati per il gioco 356194
# Recuperati dati per il gioco 356197
# Recuperati dati per il gioco 356198
# Recuperati dati per il gioco 356199
# Recuperati dati per il gioco 356203
# Recuperati dati per il gioco 356205
# Recuperati dati per il gioco 356207
# Recuperati dati per il gioco 356209
# Recuperati dati per il gioco 356212
# Recuperati dati per il gioco 356213
# Recuperati dati per il gioco 356214
# Recuperati dati per il gioco 356216
# Errore 429: Tentativo 1 - Attendo 2 secondi prima di riprovare...
# Errore 429: Tentativo 2 - Attendo 2 secondi prima di riprovare...
# Recuperati dati per il gioco 356219
# Errore 429: Tentativo 1 - Attendo 2 secondi prima di riprovare...
# Recuperati dati per il gioco 356220
# Errore 429: Tentativo 1 - Attendo 2 secondi prima di riprovare...
# Errore 429: Tentativo 3 - Attendo 4 secondi prima di riprovare...
# Recuperati dati per il gioco 356223
# Recuperati dati per il gioco 356224
# Recuperati dati per il gioco 356226
# Errore 429: Tentativo 1 - Attendo 2 secondi prima di riprovare...
# Recuperati dati per il gioco 356230
# Errore 429: Tentativo 1 - Attendo 2 secondi prima di riprovare...
# Recuperati dati per il gioco 356231
# Errore 429: Tentativo 1 - Attendo 2 secondi prima di riprovare...
# Recuperati dati per il gioco 356232
# Errore 429: Tentativo 1 - Attendo 2 secondi prima di riprovare...
# Errore 429: Tentativo 3 - Attendo 4 secondi prima di riprovare...
# Recuperati dati per il gioco 356238
# Recuperati dati per il gioco 356239
# Recuperati dati per il gioco 356245
# Recuperati dati per il gioco 356261
# Recuperati dati per il gioco 356262
# Recuperati dati per il gioco 356263
# Recuperati dati per il gioco 356264
# Recuperati dati per il gioco 356265
# Recuperati dati per il gioco 356266
# Recuperati dati per il gioco 356267
# Errore 429: Tentativo 1 - Attendo 2 secondi prima di riprovare...
# Recuperati dati per il gioco 356268
# Errore 429: Tentativo 1 - Attendo 2 secondi prima di riprovare...
# Recuperati dati per il gioco 356269
# Errore 429: Tentativo 1 - Attendo 2 secondi prima di riprovare...
# Recuperati dati per il gioco 356270
# Errore 429: Tentativo 1 - Attendo 2 secondi prima di riprovare...
# Recuperati dati per il gioco 356271
# Errore 429: Tentativo 1 - Attendo 2 secondi prima di riprovare...
# Recuperati dati per il gioco 356272
# Errore 429: Tentativo 1 - Attendo 2 secondi prima di riprovare...
# Recuperati dati per il gioco 356273
# Errore 429: Tentativo 1 - Attendo 2 secondi prima di riprovare...
# Recuperati dati per il gioco 356274
# Errore 429: Tentativo 1 - Attendo 2 secondi prima di riprovare...
# Recuperati dati per il gioco 356275
# Errore 429: Tentativo 1 - Attendo 2 secondi prima di riprovare...
# Recuperati dati per il gioco 356276
# Errore 429: Tentativo 1 - Attendo 2 secondi prima di riprovare...
# Recuperati dati per il gioco 356277
# Errore 429: Tentativo 1 - Attendo 2 secondi prima di riprovare...
# Recuperati dati per il gioco 356279
# Errore 429: Tentativo 1 - Attendo 2 secondi prima di riprovare...
# Recuperati dati per il gioco 356280
# Errore 429: Tentativo 1 - Attendo 2 secondi prima di riprovare...
# Recuperati dati per il gioco 356281
# Errore 429: Tentativo 1 - Attendo 2 secondi prima di riprovare...
# Recuperati dati per il gioco 356282
# Errore 429: Tentativo 1 - Attendo 2 secondi prima di riprovare...
# Errore 429: Tentativo 3 - Attendo 4 secondi prima di riprovare...
# Recuperati dati per il gioco 356286
# Recuperati dati per il gioco 356287
# Recuperati dati per il gioco 356289
# Errore 429: Tentativo 1 - Attendo 2 secondi prima di riprovare...
# Recuperati dati per il gioco 356290
# Errore 429: Tentativo 1 - Attendo 2 secondi prima di riprovare...
# Recuperati dati per il gioco 356291
# Errore 429: Tentativo 1 - Attendo 2 secondi prima di riprovare...
# Recuperati dati per il gioco 356292
# Errore 429: Tentativo 1 - Attendo 2 secondi prima di riprovare...
# Recuperati dati per il gioco 356293
# Errore 429: Tentativo 1 - Attendo 2 secondi prima di riprovare...
# Recuperati dati per il gioco 356294
# Errore 429: Tentativo 1 - Attendo 2 secondi prima di riprovare...
# Recuperati dati per il gioco 356296
# Errore 429: Tentativo 1 - Attendo 2 secondi prima di riprovare...
# Errore 429: Tentativo 3 - Attendo 4 secondi prima di riprovare...
# Recuperati dati per il gioco 356303
# Recuperati dati per il gioco 356304
# Recuperati dati per il gioco 356305
# Recuperati dati per il gioco 356307
# Recuperati dati per il gioco 356308
# Recuperati dati per il gioco 356309
# Errore 429: Tentativo 1 - Attendo 2 secondi prima di riprovare...
# Recuperati dati per il gioco 356312
# Recuperati dati per il gioco 356313
# Recuperati dati per il gioco 356314
# Errore 429: Tentativo 1 - Attendo 2 secondi prima di riprovare...
# Recuperati dati per il gioco 356315
# Errore 429: Tentativo 1 - Attendo 2 secondi prima di riprovare...
# Recuperati dati per il gioco 356317
# Errore 429: Tentativo 1 - Attendo 2 secondi prima di riprovare...
# Recuperati dati per il gioco 356318
# Errore 429: Tentativo 1 - Attendo 2 secondi prima di riprovare...
# Recuperati dati per il gioco 356319
# Errore 429: Tentativo 1 - Attendo 2 secondi prima di riprovare...
# Recuperati dati per il gioco 356320
# Errore 429: Tentativo 1 - Attendo 2 secondi prima di riprovare...
# Recuperati dati per il gioco 356321
# Errore 429: Tentativo 1 - Attendo 2 secondi prima di riprovare...
# Recuperati dati per il gioco 356322
# Errore 429: Tentativo 1 - Attendo 2 secondi prima di riprovare...
# Recuperati dati per il gioco 356323
# Errore 429: Tentativo 1 - Attendo 2 secondi prima di riprovare...
# Recuperati dati per il gioco 356324
# Errore 429: Tentativo 1 - Attendo 2 secondi prima di riprovare...
# Recuperati dati per il gioco 356325
# Errore 429: Tentativo 1 - Attendo 2 secondi prima di riprovare...
# Recuperati dati per il gioco 356326
# Errore 429: Tentativo 1 - Attendo 2 secondi prima di riprovare...
# Recuperati dati per il gioco 356327
# Errore 429: Tentativo 1 - Attendo 2 secondi prima di riprovare...
# Recuperati dati per il gioco 356328
# Errore 429: Tentativo 1 - Attendo 2 secondi prima di riprovare...
# Recuperati dati per il gioco 356329
# Errore 429: Tentativo 1 - Attendo 2 secondi prima di riprovare...
# Recuperati dati per il gioco 356330
# Errore 429: Tentativo 1 - Attendo 2 secondi prima di riprovare...
# Errore 429: Tentativo 3 - Attendo 4 secondi prima di riprovare...
# Recuperati dati per il gioco 356337
# Recuperati dati per il gioco 356379
# Recuperati dati per il gioco 356380
# Recuperati dati per il gioco 356381
# Recuperati dati per il gioco 356386
# Recuperati dati per il gioco 356387
# Recuperati dati per il gioco 356389
# Recuperati dati per il gioco 356390
# Recuperati dati per il gioco 356396
# Recuperati dati per il gioco 356397
# Recuperati dati per il gioco 356398
# Recuperati dati per il gioco 356399
# Recuperati dati per il gioco 356400
# Recuperati dati per il gioco 356401
# Recuperati dati per il gioco 356402
# Recuperati dati per il gioco 356404
# Recuperati dati per il gioco 356405
# Recuperati dati per il gioco 356406
# Recuperati dati per il gioco 356407
# Recuperati dati per il gioco 356408
# Recuperati dati per il gioco 356409
# Recuperati dati per il gioco 356410
# Errore 429: Tentativo 1 - Attendo 2 secondi prima di riprovare...
# Recuperati dati per il gioco 356411
# Errore 429: Tentativo 1 - Attendo 2 secondi prima di riprovare...
# Recuperati dati per il gioco 356413
# Recuperati dati per il gioco 356414
# Errore 429: Tentativo 2 - Attendo 2 secondi prima di riprovare...
# Errore 429: Tentativo 2 - Attendo 2 secondi prima di riprovare...
# Recuperati dati per il gioco 356418
# Recuperati dati per il gioco 356419
# Recuperati dati per il gioco 356420
# Errore 429: Tentativo 1 - Attendo 2 secondi prima di riprovare...
# Errore 429: Tentativo 3 - Attendo 4 secondi prima di riprovare...
# Recuperati dati per il gioco 356422
# Recuperati dati per il gioco 356423
# Recuperati dati per il gioco 356424
# Errore 429: Tentativo 1 - Attendo 2 secondi prima di riprovare...
# Recuperati dati per il gioco 356425
# Errore 429: Tentativo 1 - Attendo 2 secondi prima di riprovare...
# Recuperati dati per il gioco 356426
# Errore 429: Tentativo 1 - Attendo 2 secondi prima di riprovare...
# Recuperati dati per il gioco 356427
# Errore 429: Tentativo 1 - Attendo 2 secondi prima di riprovare...
# Recuperati dati per il gioco 356428
# Errore 429: Tentativo 1 - Attendo 2 secondi prima di riprovare...
# Recuperati dati per il gioco 356429
# Errore 429: Tentativo 1 - Attendo 2 secondi prima di riprovare...
# Recuperati dati per il gioco 356430
# Errore 429: Tentativo 1 - Attendo 2 secondi prima di riprovare...
# Recuperati dati per il gioco 356431
# Errore 429: Tentativo 1 - Attendo 2 secondi prima di riprovare...
# Recuperati dati per il gioco 356432
# Errore 429: Tentativo 1 - Attendo 2 secondi prima di riprovare...
# Recuperati dati per il gioco 356433
# Errore 429: Tentativo 1 - Attendo 2 secondi prima di riprovare...
# Recuperati dati per il gioco 356435
# Errore 429: Tentativo 1 - Attendo 2 secondi prima di riprovare...
# Recuperati dati per il gioco 356436
# Errore 429: Tentativo 1 - Attendo 2 secondi prima di riprovare...
# Recuperati dati per il gioco 356437
# Errore 429: Tentativo 1 - Attendo 2 secondi prima di riprovare...
# Recuperati dati per il gioco 356439
# Errore 429: Tentativo 1 - Attendo 2 secondi prima di riprovare...
# Recuperati dati per il gioco 356440
# Errore 429: Tentativo 1 - Attendo 2 secondi prima di riprovare...
# Recuperati dati per il gioco 356441
# Errore 429: Tentativo 1 - Attendo 2 secondi prima di riprovare...
# Recuperati dati per il gioco 356442
# Errore 429: Tentativo 1 - Attendo 2 secondi prima di riprovare...
# Recuperati dati per il gioco 356443
# Errore 429: Tentativo 1 - Attendo 2 secondi prima di riprovare...
# Recuperati dati per il gioco 356444
# Errore 429: Tentativo 1 - Attendo 2 secondi prima di riprovare...
# Recuperati dati per il gioco 356445
# Errore 429: Tentativo 1 - Attendo 2 secondi prima di riprovare...
# Recuperati dati per il gioco 356446
# Errore 429: Tentativo 1 - Attendo 2 secondi prima di riprovare...
# Recuperati dati per il gioco 356447
# Errore 429: Tentativo 1 - Attendo 2 secondi prima di riprovare...
# Recuperati dati per il gioco 356448
# Errore 429: Tentativo 1 - Attendo 2 secondi prima di riprovare...
# Recuperati dati per il gioco 356449
# Errore 429: Tentativo 1 - Attendo 2 secondi prima di riprovare...
# Recuperati dati per il gioco 356450
# Errore 429: Tentativo 1 - Attendo 2 secondi prima di riprovare...
# Recuperati dati per il gioco 356451
# Errore 429: Tentativo 1 - Attendo 2 secondi prima di riprovare...
# Errore 429: Tentativo 3 - Attendo 4 secondi prima di riprovare...
# Recuperati dati per il gioco 356454
# Recuperati dati per il gioco 356455
# Recuperati dati per il gioco 356456
# Recuperati dati per il gioco 356457
# Recuperati dati per il gioco 356458
# Errore 429: Tentativo 1 - Attendo 2 secondi prima di riprovare...
# Recuperati dati per il gioco 356459
# Errore 429: Tentativo 1 - Attendo 2 secondi prima di riprovare...
# Recuperati dati per il gioco 356461
# Recuperati dati per il gioco 356462
# Recuperati dati per il gioco 356463
# Errore 429: Tentativo 1 - Attendo 2 secondi prima di riprovare...
# Recuperati dati per il gioco 356464
# Errore 429: Tentativo 1 - Attendo 2 secondi prima di riprovare...
# Recuperati dati per il gioco 356465
# Errore 429: Tentativo 1 - Attendo 2 secondi prima di riprovare...
# Recuperati dati per il gioco 356466
# Errore 429: Tentativo 1 - Attendo 2 secondi prima di riprovare...
# Errore 429: Tentativo 3 - Attendo 4 secondi prima di riprovare...
# Recuperati dati per il gioco 356468
# Recuperati dati per il gioco 356469
# Recuperati dati per il gioco 356470
# Errore 429: Tentativo 1 - Attendo 2 secondi prima di riprovare...
# Recuperati dati per il gioco 356471
# Errore 429: Tentativo 1 - Attendo 2 secondi prima di riprovare...
# Recuperati dati per il gioco 356472
# Errore 429: Tentativo 1 - Attendo 2 secondi prima di riprovare...
# Recuperati dati per il gioco 356473
# Errore 429: Tentativo 1 - Attendo 2 secondi prima di riprovare...
# Recuperati dati per il gioco 356474
# Errore 429: Tentativo 1 - Attendo 2 secondi prima di riprovare...
# Errore 429: Tentativo 3 - Attendo 4 secondi prima di riprovare...
# Recuperati dati per il gioco 356477
# Recuperati dati per il gioco 356481
# Recuperati dati per il gioco 356482
# Recuperati dati per il gioco 356483
# Recuperati dati per il gioco 356484
# Recuperati dati per il gioco 356485
# Recuperati dati per il gioco 356487
# Recuperati dati per il gioco 356489
# Recuperati dati per il gioco 356492
# Recuperati dati per il gioco 356493
# Recuperati dati per il gioco 356494
# Recuperati dati per il gioco 356495
# Recuperati dati per il gioco 356496
# Errore 429: Tentativo 1 - Attendo 2 secondi prima di riprovare...
# Errore 429: Tentativo 2 - Attendo 2 secondi prima di riprovare...
# Recuperati dati per il gioco 356510
# Recuperati dati per il gioco 356523
# Recuperati dati per il gioco 356524
# Recuperati dati per il gioco 356541
# Recuperati dati per il gioco 356554
# Recuperati dati per il gioco 356556
# Recuperati dati per il gioco 356559
# Recuperati dati per il gioco 356566
# Recuperati dati per il gioco 356567
# Recuperati dati per il gioco 356568
# Recuperati dati per il gioco 356569
# Recuperati dati per il gioco 356570
# Recuperati dati per il gioco 356571
# Recuperati dati per il gioco 356572
# Errore 429: Tentativo 1 - Attendo 2 secondi prima di riprovare...
# Recuperati dati per il gioco 356573
# Errore 429: Tentativo 1 - Attendo 2 secondi prima di riprovare...
# Recuperati dati per il gioco 356574
# Errore 429: Tentativo 1 - Attendo 2 secondi prima di riprovare...
# Recuperati dati per il gioco 356575
# Errore 429: Tentativo 1 - Attendo 2 secondi prima di riprovare...
# Recuperati dati per il gioco 356576
# Errore 429: Tentativo 1 - Attendo 2 secondi prima di riprovare...
# Recuperati dati per il gioco 356578
# Recuperati dati per il gioco 356580
# Recuperati dati per il gioco 356582
# Recuperati dati per il gioco 356586
# Recuperati dati per il gioco 356587
# Recuperati dati per il gioco 356590
# Errore 429: Tentativo 1 - Attendo 2 secondi prima di riprovare...
# Recuperati dati per il gioco 356591
# Errore 429: Tentativo 1 - Attendo 2 secondi prima di riprovare...
# Errore 429: Tentativo 3 - Attendo 4 secondi prima di riprovare...
# Recuperati dati per il gioco 356597
# Recuperati dati per il gioco 356598
# Errore 429: Tentativo 2 - Attendo 2 secondi prima di riprovare...
# Recuperati dati per il gioco 356600
# Recuperati dati per il gioco 356601
# Recuperati dati per il gioco 356602
# Recuperati dati per il gioco 356604
# Recuperati dati per il gioco 356605
# Recuperati dati per il gioco 356606
# Errore 429: Tentativo 1 - Attendo 2 secondi prima di riprovare...
# Recuperati dati per il gioco 356607
# Errore 429: Tentativo 1 - Attendo 2 secondi prima di riprovare...
# Recuperati dati per il gioco 356608
# Errore 429: Tentativo 1 - Attendo 2 secondi prima di riprovare...
# Recuperati dati per il gioco 356609
# Errore 429: Tentativo 1 - Attendo 2 secondi prima di riprovare...
# Recuperati dati per il gioco 356610
# Errore 429: Tentativo 1 - Attendo 2 secondi prima di riprovare...
# Recuperati dati per il gioco 356611
# Errore 429: Tentativo 1 - Attendo 2 secondi prima di riprovare...
# Errore 429: Tentativo 3 - Attendo 4 secondi prima di riprovare...
# Recuperati dati per il gioco 356615
# Recuperati dati per il gioco 356618
# Recuperati dati per il gioco 356619
# Recuperati dati per il gioco 356620
# Recuperati dati per il gioco 356621
# Recuperati dati per il gioco 356622
# Errore 429: Tentativo 1 - Attendo 2 secondi prima di riprovare...
# Recuperati dati per il gioco 356623
# Errore 429: Tentativo 1 - Attendo 2 secondi prima di riprovare...
# Errore 429: Tentativo 3 - Attendo 4 secondi prima di riprovare...
# Recuperati dati per il gioco 356625
# Recuperati dati per il gioco 356626
# Errore 429: Tentativo 2 - Attendo 2 secondi prima di riprovare...
# Recuperati dati per il gioco 356629
# Recuperati dati per il gioco 356630
# Errore 429: Tentativo 1 - Attendo 2 secondi prima di riprovare...
# Errore 429: Tentativo 1 - Attendo 2 secondi prima di riprovare...
# Errore 429: Tentativo 3 - Attendo 4 secondi prima di riprovare...
# Recuperati dati per il gioco 356637
# Recuperati dati per il gioco 356640
# Recuperati dati per il gioco 356641
# Recuperati dati per il gioco 356645
# Recuperati dati per il gioco 356646
# Recuperati dati per il gioco 356647
# Recuperati dati per il gioco 356655
# Recuperati dati per il gioco 356656
# Recuperati dati per il gioco 356657
# Recuperati dati per il gioco 356658
# Recuperati dati per il gioco 356659
# Errore 429: Tentativo 1 - Attendo 2 secondi prima di riprovare...
# Recuperati dati per il gioco 356660
# Errore 429: Tentativo 1 - Attendo 2 secondi prima di riprovare...
# Errore 429: Tentativo 2 - Attendo 2 secondi prima di riprovare...
# Errore 429: Tentativo 2 - Attendo 2 secondi prima di riprovare...
# Recuperati dati per il gioco 356679
# Recuperati dati per il gioco 356681
# Recuperati dati per il gioco 356708
# Recuperati dati per il gioco 356709
# Recuperati dati per il gioco 356710
# Recuperati dati per il gioco 356713
# Recuperati dati per il gioco 356716
# Recuperati dati per il gioco 356726
# ...
# Recuperati dati per il gioco 358755
# Errore 429: Tentativo 1 - Attendo 2 secondi prima di riprovare...
# Recuperati dati per il gioco 358756
# Errore 429: Tentativo 1 - Attendo 2 secondi prima di riprovare...
# Recuperati dati per il gioco 358757
# Errore 429: Tentativo 1 - Attendo 2 secondi prima di riprovare...
# Recuperati dati per il gioco 358758
# Errore 429: Tentativo 1 - Attendo 2 secondi prima di riprovare...
# Recuperati dati per il gioco 358760
# Recuperati dati per il gioco 358761
# Errore 429: Tentativo 2 - Attendo 2 secondi prima di riprovare...
# Recuperati dati per il gioco 358763
# Recuperati dati per il gioco 358765
# Errore 429: Tentativo 1 - Attendo 2 secondi prima di riprovare...
# Recuperati dati per il gioco 358766
# Errore 429: Tentativo 1 - Attendo 2 secondi prima di riprovare...
# Errore 429: Tentativo 1 - Attendo 2 secondi prima di riprovare...
# Errore 429: Tentativo 2 - Attendo 2 secondi prima di riprovare...
# Recuperati dati per il gioco 358773
# Recuperati dati per il gioco 358779
# Recuperati dati per il gioco 358780
# Recuperati dati per il gioco 358783
# Recuperati dati per il gioco 358787
# Recuperati dati per il gioco 358790
# Recuperati dati per il gioco 358791
# Recuperati dati per il gioco 358792
# Recuperati dati per il gioco 358794
# Recuperati dati per il gioco 358796
# Recuperati dati per il gioco 358799
# Recuperati dati per il gioco 358800
# Recuperati dati per il gioco 358802
# Recuperati dati per il gioco 358805
# Recuperati dati per il gioco 358807
# Recuperati dati per il gioco 358808
# Recuperati dati per il gioco 358811
# Recuperati dati per il gioco 358812
# Recuperati dati per il gioco 358813
# Recuperati dati per il gioco 358814
# Recuperati dati per il gioco 358815
# Recuperati dati per il gioco 358816
# Recuperati dati per il gioco 358817
# Errore 429: Tentativo 1 - Attendo 2 secondi prima di riprovare...
# Recuperati dati per il gioco 358818
# Errore 429: Tentativo 1 - Attendo 2 secondi prima di riprovare...
# Recuperati dati per il gioco 358819
# Errore 429: Tentativo 1 - Attendo 2 secondi prima di riprovare...
# Errore 429: Tentativo 3 - Attendo 4 secondi prima di riprovare...
# Recuperati dati per il gioco 358823
# Recuperati dati per il gioco 358824
# Recuperati dati per il gioco 358825
# Errore 429: Tentativo 1 - Attendo 2 secondi prima di riprovare...
# Recuperati dati per il gioco 358826
# Errore 429: Tentativo 1 - Attendo 2 secondi prima di riprovare...
# Errore 429: Tentativo 2 - Attendo 2 secondi prima di riprovare...
# Recuperati dati per il gioco 358830
# Errore 429: Tentativo 1 - Attendo 2 secondi prima di riprovare...
# Errore 429: Tentativo 3 - Attendo 4 secondi prima di riprovare...
# Recuperati dati per il gioco 358833
# Recuperati dati per il gioco 358836
# Recuperati dati per il gioco 358837
# Recuperati dati per il gioco 358839
# Recuperati dati per il gioco 358840
# Errore 429: Tentativo 1 - Attendo 2 secondi prima di riprovare...
# Recuperati dati per il gioco 358841
# Errore 429: Tentativo 1 - Attendo 2 secondi prima di riprovare...
# Recuperati dati per il gioco 358843
# Errore 429: Tentativo 1 - Attendo 2 secondi prima di riprovare...
# Recuperati dati per il gioco 358844
# Errore 429: Tentativo 1 - Attendo 2 secondi prima di riprovare...
# Errore 429: Tentativo 3 - Attendo 4 secondi prima di riprovare...
# Recuperati dati per il gioco 358849
# Recuperati dati per il gioco 358850
# Recuperati dati per il gioco 358854
# Recuperati dati per il gioco 358856
# Recuperati dati per il gioco 358857
# Recuperati dati per il gioco 358858
# Errore 429: Tentativo 1 - Attendo 2 secondi prima di riprovare...
# Recuperati dati per il gioco 358860
# Recuperati dati per il gioco 358861
# Recuperati dati per il gioco 358862
# Errore 429: Tentativo 1 - Attendo 2 secondi prima di riprovare...
# Recuperati dati per il gioco 358863
# Errore 429: Tentativo 1 - Attendo 2 secondi prima di riprovare...
# Recuperati dati per il gioco 358864
# Errore 429: Tentativo 1 - Attendo 2 secondi prima di riprovare...
# Recuperati dati per il gioco 358865
# Errore 429: Tentativo 1 - Attendo 2 secondi prima di riprovare...
# Recuperati dati per il gioco 358866
# Errore 429: Tentativo 1 - Attendo 2 secondi prima di riprovare...
# Recuperati dati per il gioco 358867
# Errore 429: Tentativo 1 - Attendo 2 secondi prima di riprovare...
# Recuperati dati per il gioco 358868
# Errore 429: Tentativo 1 - Attendo 2 secondi prima di riprovare...
# Recuperati dati per il gioco 358869
# Errore 429: Tentativo 1 - Attendo 2 secondi prima di riprovare...
# Recuperati dati per il gioco 358870
# Errore 429: Tentativo 1 - Attendo 2 secondi prima di riprovare...
# Recuperati dati per il gioco 358871
# Errore 429: Tentativo 1 - Attendo 2 secondi prima di riprovare...
# Recuperati dati per il gioco 358872
# Errore 429: Tentativo 1 - Attendo 2 secondi prima di riprovare...
# Recuperati dati per il gioco 358873
# Errore 429: Tentativo 1 - Attendo 2 secondi prima di riprovare...
# Recuperati dati per il gioco 358874
# Errore 429: Tentativo 1 - Attendo 2 secondi prima di riprovare...
# Recuperati dati per il gioco 358875
# Errore 429: Tentativo 1 - Attendo 2 secondi prima di riprovare...
# Recuperati dati per il gioco 358876
# Errore 429: Tentativo 1 - Attendo 2 secondi prima di riprovare...
# Recuperati dati per il gioco 358877
# Errore 429: Tentativo 1 - Attendo 2 secondi prima di riprovare...
# Recuperati dati per il gioco 358878
# Errore 429: Tentativo 1 - Attendo 2 secondi prima di riprovare...
# Recuperati dati per il gioco 358879
# Errore 429: Tentativo 1 - Attendo 2 secondi prima di riprovare...
# Recuperati dati per il gioco 358880
# Errore 429: Tentativo 1 - Attendo 2 secondi prima di riprovare...
# Recuperati dati per il gioco 358890
# Recuperati dati per il gioco 358905
# Recuperati dati per il gioco 358906
# Recuperati dati per il gioco 358908
# Recuperati dati per il gioco 358909
# Recuperati dati per il gioco 358910
# Recuperati dati per il gioco 358912
# Recuperati dati per il gioco 358918
# Recuperati dati per il gioco 358919
# Recuperati dati per il gioco 358920
# Recuperati dati per il gioco 358921
# Recuperati dati per il gioco 358922
# Recuperati dati per il gioco 358926
# Recuperati dati per il gioco 358927
# Recuperati dati per il gioco 358928
# Recuperati dati per il gioco 358929
# Recuperati dati per il gioco 358930
# Recuperati dati per il gioco 358931
# Recuperati dati per il gioco 358932
# Recuperati dati per il gioco 358934
# Recuperati dati per il gioco 358935
# Recuperati dati per il gioco 358937
# Recuperati dati per il gioco 358939
# Errore 429: Tentativo 1 - Attendo 2 secondi prima di riprovare...
# Recuperati dati per il gioco 358940
# Errore 429: Tentativo 1 - Attendo 2 secondi prima di riprovare...
# Recuperati dati per il gioco 358941
# Errore 429: Tentativo 1 - Attendo 2 secondi prima di riprovare...
# Errore 429: Tentativo 3 - Attendo 4 secondi prima di riprovare...
# Recuperati dati per il gioco 358949
# Recuperati dati per il gioco 358966
# Recuperati dati per il gioco 358971
# Recuperati dati per il gioco 358974
# Recuperati dati per il gioco 358976
# Recuperati dati per il gioco 358980
# Recuperati dati per il gioco 358981
# Recuperati dati per il gioco 358984
# Recuperati dati per il gioco 358987
# Recuperati dati per il gioco 358988
# Recuperati dati per il gioco 358990
# Recuperati dati per il gioco 358991
# Recuperati dati per il gioco 358995
# Recuperati dati per il gioco 358998
# Recuperati dati per il gioco 359002
# Recuperati dati per il gioco 359003
# Recuperati dati per il gioco 359004
# Errore 429: Tentativo 1 - Attendo 2 secondi prima di riprovare...
# Recuperati dati per il gioco 359009
# Recuperati dati per il gioco 359011
# Recuperati dati per il gioco 359014
# Recuperati dati per il gioco 359016
# Errore 429: Tentativo 1 - Attendo 2 secondi prima di riprovare...
# Recuperati dati per il gioco 359017
# Errore 429: Tentativo 1 - Attendo 2 secondi prima di riprovare...
# Recuperati dati per il gioco 359018
# Errore 429: Tentativo 1 - Attendo 2 secondi prima di riprovare...
# Recuperati dati per il gioco 359019
# Errore 429: Tentativo 1 - Attendo 2 secondi prima di riprovare...
# Recuperati dati per il gioco 359020
# Errore 429: Tentativo 1 - Attendo 2 secondi prima di riprovare...
# Recuperati dati per il gioco 359021
# Errore 429: Tentativo 1 - Attendo 2 secondi prima di riprovare...
# Recuperati dati per il gioco 359022
# Errore 429: Tentativo 1 - Attendo 2 secondi prima di riprovare...
# Recuperati dati per il gioco 359023
# Errore 429: Tentativo 1 - Attendo 2 secondi prima di riprovare...
# Errore 429: Tentativo 3 - Attendo 4 secondi prima di riprovare...
# Recuperati dati per il gioco 359025
# Recuperati dati per il gioco 359026
# Recuperati dati per il gioco 359027
# Errore 429: Tentativo 1 - Attendo 2 secondi prima di riprovare...
# Recuperati dati per il gioco 359028
# Errore 429: Tentativo 1 - Attendo 2 secondi prima di riprovare...
# Recuperati dati per il gioco 359029
# Errore 429: Tentativo 1 - Attendo 2 secondi prima di riprovare...
# Recuperati dati per il gioco 359030
# Errore 429: Tentativo 1 - Attendo 2 secondi prima di riprovare...
# Recuperati dati per il gioco 359031
# Errore 429: Tentativo 1 - Attendo 2 secondi prima di riprovare...
# Recuperati dati per il gioco 359032
# Errore 429: Tentativo 1 - Attendo 2 secondi prima di riprovare...
# Recuperati dati per il gioco 359033
# Errore 429: Tentativo 1 - Attendo 2 secondi prima di riprovare...
# Recuperati dati per il gioco 359034
# Errore 429: Tentativo 1 - Attendo 2 secondi prima di riprovare...
# Recuperati dati per il gioco 359035
# Errore 429: Tentativo 1 - Attendo 2 secondi prima di riprovare...
# Recuperati dati per il gioco 359036
# Errore 429: Tentativo 1 - Attendo 2 secondi prima di riprovare...
# Recuperati dati per il gioco 359037
# Errore 429: Tentativo 1 - Attendo 2 secondi prima di riprovare...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 4
#       2 game_ids = range(354623,400000)  # La lista di ID di giochi che vuoi recuperare
#       3 for game_id in game_ids:
# ----> 4     get_data_with_backoff(game_id)
#       6 # Stampa i dati raccolti o esegui altre operazioni
#       7 print(f"Totale giochi recuperati: {len(games_data)}")
#
# Cell In[2], line 8, in get_data_with_backoff(game_id, max_retries)
#       6 for i in range(max_retries):
#       7     try:
# ----> 8         response = requests.get(url)
#       9         response.raise_for_status()
#      10         time.sleep(1)  # Pausa per evitare di sovraccaricare l'API
#
# File ~/.local/lib/python3.12/site-packages/requests/api.py:73, in get(url, params, **kwargs)
#      62 def get(url, params=None, **kwargs):
#      63     r"""Sends a GET request.
#      64
#      65     :param url: URL for the new :class:`Request` object.
#    (...)
#      70     :rtype: requests.Response
#      71     """
# ---> 73     return request("get", url, params=params, **kwargs)
#
# File ~/.local/lib/python3.12/site-packages/requests/api.py:59, in request(method, url, **kwargs)
#      55 # By using the 'with' statement we are sure the session is closed, thus we
#      56 # avoid leaving sockets open which can trigger a ResourceWarning in some
#      57 # cases, and look like a memory leak in others.
#      58 with sessions.Session() as session:
# ---> 59     return session.request(method=method, url=url, **kwargs)
#
# File ~/.local/lib/python3.12/site-packages/requests/sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     584 send_kwargs = {
#     585     "timeout": timeout,
#     586     "allow_redirects": allow_redirects,
#     587 }
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File ~/.local/lib/python3.12/site-packages/requests/sessions.py:703, in Session.send(self, request, **kwargs)
#     700 start = preferred_clock()
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#     706 elapsed = preferred_clock() - start
#
# File ~/.local/lib/python3.12/site-packages/requests/adapters.py:667, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     664     timeout = TimeoutSauce(connect=timeout, read=timeout)
#     666 try:
# --> 667     resp = conn.urlopen(
#     668         method=request.method,
#     669         url=url,
#     670         body=request.body,
#     671         headers=request.headers,
#     672         redirect=False,
#     673         assert_same_host=False,
#     674         preload_content=False,
#     675         decode_content=False,
#     676         retries=self.max_retries,
#     677         timeout=timeout,
#     678         chunked=chunked,
#     679     )
#     681 except (ProtocolError, OSError) as err:
#     682     raise ConnectionError(err, request=request)
#
# File ~/.local/lib/python3.12/site-packages/urllib3/connectionpool.py:789, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     786 response_conn = conn if not release_conn else None
#     788 # Make the request on the HTTPConnection object
# --> 789 response = self._make_request(
#     790     conn,
#     791     method,
#     792     url,
#     793     timeout=timeout_obj,
#     794     body=body,
#     795     headers=headers,
#     796     chunked=chunked,
#     797     retries=retries,
#     798     response_conn=response_conn,
#     799     preload_content=preload_content,
#     800     decode_content=decode_content,
#     801     **response_kw,
#     802 )
#     804 # Everything went great!
#     805 clean_exit = True
#
# File ~/.local/lib/python3.12/site-packages/urllib3/connectionpool.py:536, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     534 # Receive the response from the server
#     535 try:
# --> 536     response = conn.getresponse()
#     537 except (BaseSSLError, OSError) as e:
#     538     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# File ~/.local/lib/python3.12/site-packages/urllib3/connection.py:507, in HTTPConnection.getresponse(self)
#     504 from .response import HTTPResponse
#     506 # Get the response from http.client.HTTPConnection
# --> 507 httplib_response = super().getresponse()
#     509 try:
#     510     assert_header_parsing(httplib_response.msg)
#
# File /usr/local/python/3.12.1/lib/python3.12/http/client.py:1419, in HTTPConnection.getresponse(self)
#    1417 try:
#    1418     try:
# -> 1419         response.begin()
#    1420     except ConnectionError:
#    1421         self.close()
#
# File /usr/local/python/3.12.1/lib/python3.12/http/client.py:331, in HTTPResponse.begin(self)
#     329 # read until we get a non-100 response
#     330 while True:
# --> 331     version, status, reason = self._read_status()
#     332     if status != CONTINUE:
#     333         break
#
# File /usr/local/python/3.12.1/lib/python3.12/http/client.py:292, in HTTPResponse._read_status(self)
#     291 def _read_status(self):
# --> 292     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     293     if len(line) > _MAXLINE:
#     294         raise LineTooLong("status line")
#
# File /usr/local/python/3.12.1/lib/python3.12/socket.py:707, in SocketIO.readinto(self, b)
#     705 while True:
#     706     try:
# --> 707         return self._sock.recv_into(b)
#     708     except timeout:
#     709         self._timeout_occurred = True
#
# File /usr/local/python/3.12.1/lib/python3.12/ssl.py:1253, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1249     if flags != 0:
#    1250         raise ValueError(
#    1251           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1252           self.__class__)
# -> 1253     return self.read(nbytes, buffer)
#    1254 else:
#    1255     return super().recv_into(buffer, nbytes, flags)
#
# File /usr/local/python/3.12.1/lib/python3.12/ssl.py:1105, in SSLSocket.read(self, len, buffer)
#    1103 try:
#    1104     if buffer is not None:
# -> 1105         return self._sslobj.read(len, buffer)
#    1106     else:
#    1107         return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %%
import pandas as pd
# Creazione del DataFrame
games_df = pd.DataFrame(games_data)

# Salva i dati in un file CSV
games_df.to_csv("games_2022caggioa_to_present.csv", index=False)
print("Dati salvati in games_2022_to_present.csv")
# Out:
# Dati salvati in games_2022_to_present.csv
