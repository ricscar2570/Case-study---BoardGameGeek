# %%
games_data = []  # Assicurati che la lista sia inizializzata

import time
import requests
import xml.etree.ElementTree as ET

# %%
games_data = []  # Assicurati che la lista sia inizializzata

def get_data_with_backoff(game_id, max_retries=5):
    url = f"https://boardgamegeek.com/xmlapi2/thing?id={game_id}&stats=1"
    delay = 2  # Ritardo iniziale in secondi
    for i in range(max_retries):
        try:
            response = requests.get(url)
            response.raise_for_status()
            time.sleep(1)  # Pausa per evitare di sovraccaricare l'API

            # Parsing XML
            root = ET.fromstring(response.content)
            item = root.find("item")
            
            # Verifica presenza di dati
            if item is not None:
                # Usa il metodo `find` in modo sicuro con un controllo per ogni elemento
                year_published = item.find("yearpublished")
                year_published = int(year_published.get("value", 0)) if year_published is not None else None
                
                # Filtra solo i giochi dal 2022 in poi
                if year_published and year_published >= 2022:
                    game_info = {
                        "BGGId": game_id,
                        "Name": item.find("name").get("value") if item.find("name") is not None else "N/A",
                        "YearPublished": year_published,
                        "GameWeight": float(item.find("statistics/ratings/averageweight").get("value", 0)) if item.find("statistics/ratings/averageweight") is not None else 0,
                        "AvgRating": float(item.find("statistics/ratings/average").get("value", 0)) if item.find("statistics/ratings/average") is not None else 0,
                        "BayesAvgRating": float(item.find("statistics/ratings/bayesaverage").get("value", 0)) if item.find("statistics/ratings/bayesaverage") is not None else 0,
                        "NumOwned": int(item.find("statistics/ratings/owned").get("value", 0)) if item.find("statistics/ratings/owned") is not None else 0,
                        "NumComments": int(item.find("statistics/ratings/numcomments").get("value", 0)) if item.find("statistics/ratings/numcomments") is not None else 0,
                        "NumUserRatings": int(item.find("statistics/ratings/usersrated").get("value", 0)) if item.find("statistics/ratings/usersrated") is not None else 0,
                        "MinPlayers": int(item.find("minplayers").get("value", 1)) if item.find("minplayers") is not None else 1,
                        "MaxPlayers": int(item.find("maxplayers").get("value", 1)) if item.find("maxplayers") is not None else 1,
                        "MinPlaytime": int(item.find("minplaytime").get("value", 0)) if item.find("minplaytime") is not None else 0,
                        "MaxPlaytime": int(item.find("maxplaytime").get("value", 0)) if item.find("maxplaytime") is not None else 0,
                        "AgeRec": int(item.find("minage").get("value", 0)) if item.find("minage") is not None else 0,
                        "Description": item.find("description").text.strip() if item.find("description") is not None else ""
                    }
                    games_data.append(game_info)
                    print(f"Recuperati dati per il gioco {game_id}")
                    return game_info  # Esce dalla funzione se il recupero ha successo

        except requests.exceptions.HTTPError as e:
            if response.status_code == 429:
                print(f"Errore 429: Tentativo {i + 1} - Attendo {delay} secondi prima di riprovare...")
                time.sleep(delay)
                delay *= 2  # Raddoppia il ritardo
            else:
                print(f"Errore nel recuperare i dati per il gioco {game_id}: {e}")
                break
        except Exception as e:
            print(f"Errore generico per il gioco {game_id}: {e}")
            break

    return None  # Ritorna None se non riesce dopo max_retries tentativi

# %%
# Esegui per ogni ID di gioco
game_ids = range(350186,400000)  # La lista di ID di giochi che vuoi recuperare
for game_id in game_ids:
    get_data_with_backoff(game_id)

# Stampa i dati raccolti o esegui altre operazioni
print(f"Totale giochi recuperati: {len(games_data)}")
# Out:
# Recuperati dati per il gioco 350196
# Recuperati dati per il gioco 350197
# Recuperati dati per il gioco 350198
# Recuperati dati per il gioco 350203
# Recuperati dati per il gioco 350204
# Recuperati dati per il gioco 350205
# Recuperati dati per il gioco 350212
# Recuperati dati per il gioco 350240
# Recuperati dati per il gioco 350241
# Recuperati dati per il gioco 350247
# Recuperati dati per il gioco 350254
# Recuperati dati per il gioco 350255
# Recuperati dati per il gioco 350256
# Recuperati dati per il gioco 350257
# Recuperati dati per il gioco 350258
# Recuperati dati per il gioco 350259
# Recuperati dati per il gioco 350260
# Recuperati dati per il gioco 350316
# Recuperati dati per il gioco 350323
# Recuperati dati per il gioco 350327
# Recuperati dati per il gioco 350333
# Recuperati dati per il gioco 350338
# Recuperati dati per il gioco 350348
# Recuperati dati per il gioco 350386
# Recuperati dati per il gioco 350387
# Recuperati dati per il gioco 350388
# Recuperati dati per il gioco 350389
# Recuperati dati per il gioco 350421
# Recuperati dati per il gioco 350428
# Recuperati dati per il gioco 350430
# Recuperati dati per il gioco 350431
# Recuperati dati per il gioco 350458
# Recuperati dati per il gioco 350459
# Recuperati dati per il gioco 350460
# Recuperati dati per il gioco 350461
# Recuperati dati per il gioco 350462
# Recuperati dati per il gioco 350463
# Recuperati dati per il gioco 350464
# Recuperati dati per il gioco 350465
# Recuperati dati per il gioco 350466
# Recuperati dati per il gioco 350467
# Recuperati dati per il gioco 350469
# Recuperati dati per il gioco 350471
# Recuperati dati per il gioco 350527
# Recuperati dati per il gioco 350560
# Recuperati dati per il gioco 350610
# Recuperati dati per il gioco 350611
# Recuperati dati per il gioco 350621
# Recuperati dati per il gioco 350623
# Recuperati dati per il gioco 350624
# Recuperati dati per il gioco 350627
# Recuperati dati per il gioco 350637
# Recuperati dati per il gioco 350670
# Recuperati dati per il gioco 350689
# Recuperati dati per il gioco 350692
# Recuperati dati per il gioco 350707
# Recuperati dati per il gioco 350713
# Recuperati dati per il gioco 350714
# Recuperati dati per il gioco 350718
# Recuperati dati per il gioco 350720
# Recuperati dati per il gioco 350729
# Recuperati dati per il gioco 350731
# Recuperati dati per il gioco 350732
# Recuperati dati per il gioco 350733
# Recuperati dati per il gioco 350734
# Recuperati dati per il gioco 350735
# Recuperati dati per il gioco 350748
# Recuperati dati per il gioco 350749
# Recuperati dati per il gioco 350750
# Recuperati dati per il gioco 350753
# Recuperati dati per il gioco 350755
# Recuperati dati per il gioco 350764
# Recuperati dati per il gioco 350765
# Recuperati dati per il gioco 350782
# Recuperati dati per il gioco 350784
# Recuperati dati per il gioco 350863
# Recuperati dati per il gioco 350921
# Recuperati dati per il gioco 350933
# Recuperati dati per il gioco 350945
# Recuperati dati per il gioco 350947
# Recuperati dati per il gioco 350948
# Recuperati dati per il gioco 350951
# Recuperati dati per il gioco 350953
# Recuperati dati per il gioco 350954
# Recuperati dati per il gioco 350955
# Recuperati dati per il gioco 350960
# Recuperati dati per il gioco 350987
# Recuperati dati per il gioco 350992
# Recuperati dati per il gioco 350994
# Recuperati dati per il gioco 351038
# Recuperati dati per il gioco 351040
# Recuperati dati per il gioco 351077
# Recuperati dati per il gioco 351090
# Recuperati dati per il gioco 351097
# Recuperati dati per il gioco 351098
# Recuperati dati per il gioco 351113
# Recuperati dati per il gioco 351140
# Recuperati dati per il gioco 351142
# Recuperati dati per il gioco 351143
# Recuperati dati per il gioco 351147
# Recuperati dati per il gioco 351149
# Recuperati dati per il gioco 351159
# Recuperati dati per il gioco 351180
# Recuperati dati per il gioco 351192
# Recuperati dati per il gioco 351208
# Recuperati dati per il gioco 351226
# Recuperati dati per il gioco 351292
# Recuperati dati per il gioco 351294
# Recuperati dati per il gioco 351296
# Recuperati dati per il gioco 351297
# Recuperati dati per il gioco 351298
# Recuperati dati per il gioco 351299
# Recuperati dati per il gioco 351300
# Recuperati dati per il gioco 351356
# Recuperati dati per il gioco 351363
# Recuperati dati per il gioco 351373
# Recuperati dati per il gioco 351375
# Recuperati dati per il gioco 351376
# Recuperati dati per il gioco 351377
# Recuperati dati per il gioco 351378
# Recuperati dati per il gioco 351379
# Recuperati dati per il gioco 351380
# Recuperati dati per il gioco 351381
# Recuperati dati per il gioco 351382
# Recuperati dati per il gioco 351384
# Recuperati dati per il gioco 351385
# Recuperati dati per il gioco 351386
# Recuperati dati per il gioco 351391
# Recuperati dati per il gioco 351393
# Recuperati dati per il gioco 351422
# Recuperati dati per il gioco 351476
# Recuperati dati per il gioco 351486
# Recuperati dati per il gioco 351499
# Recuperati dati per il gioco 351503
# Recuperati dati per il gioco 351526
# Recuperati dati per il gioco 351535
# Recuperati dati per il gioco 351538
# Recuperati dati per il gioco 351540
# Recuperati dati per il gioco 351544
# Recuperati dati per il gioco 351549
# Recuperati dati per il gioco 351550
# Recuperati dati per il gioco 351552
# Recuperati dati per il gioco 351560
# Recuperati dati per il gioco 351570
# Recuperati dati per il gioco 351582
# Recuperati dati per il gioco 351594
# Recuperati dati per il gioco 351600
# Recuperati dati per il gioco 351603
# Recuperati dati per il gioco 351605
# Recuperati dati per il gioco 351611
# Recuperati dati per il gioco 351615
# Recuperati dati per il gioco 351616
# Recuperati dati per il gioco 351627
# Recuperati dati per il gioco 351644
# Recuperati dati per il gioco 351648
# Recuperati dati per il gioco 351651
# Recuperati dati per il gioco 351665
# Recuperati dati per il gioco 351671
# Recuperati dati per il gioco 351716
# Recuperati dati per il gioco 351717
# Recuperati dati per il gioco 351725
# Recuperati dati per il gioco 351765
# Recuperati dati per il gioco 351800
# Recuperati dati per il gioco 351804
# Recuperati dati per il gioco 351812
# Recuperati dati per il gioco 351814
# Recuperati dati per il gioco 351817
# Recuperati dati per il gioco 351818
# Recuperati dati per il gioco 351849
# Recuperati dati per il gioco 351855
# Recuperati dati per il gioco 351857
# Recuperati dati per il gioco 351863
# Recuperati dati per il gioco 351865
# Recuperati dati per il gioco 351867
# Recuperati dati per il gioco 351869
# Recuperati dati per il gioco 351876
# Recuperati dati per il gioco 351885
# Recuperati dati per il gioco 351896
# Recuperati dati per il gioco 351904
# Recuperati dati per il gioco 351908
# Recuperati dati per il gioco 351913
# Recuperati dati per il gioco 351916
# Recuperati dati per il gioco 351937
# Recuperati dati per il gioco 351956
# Recuperati dati per il gioco 351959
# Recuperati dati per il gioco 351964
# Recuperati dati per il gioco 351969
# Recuperati dati per il gioco 351972
# Recuperati dati per il gioco 351991
# Recuperati dati per il gioco 351992
# Recuperati dati per il gioco 351998
# Recuperati dati per il gioco 352029
# Recuperati dati per il gioco 352036
# Recuperati dati per il gioco 352037
# Recuperati dati per il gioco 352050
# Recuperati dati per il gioco 352052
# Recuperati dati per il gioco 352126
# Recuperati dati per il gioco 352135
# Recuperati dati per il gioco 352138
# Recuperati dati per il gioco 352145
# Recuperati dati per il gioco 352162
# Recuperati dati per il gioco 352179
# Recuperati dati per il gioco 352201
# Recuperati dati per il gioco 352218
# Recuperati dati per il gioco 352222
# Recuperati dati per il gioco 352223
# Recuperati dati per il gioco 352225
# Recuperati dati per il gioco 352241
# Recuperati dati per il gioco 352242
# Recuperati dati per il gioco 352243
# Recuperati dati per il gioco 352244
# Recuperati dati per il gioco 352260
# Recuperati dati per il gioco 352263
# Recuperati dati per il gioco 352311
# Recuperati dati per il gioco 352344
# Recuperati dati per il gioco 352358
# Recuperati dati per il gioco 352379
# Recuperati dati per il gioco 352395
# Recuperati dati per il gioco 352409
# Recuperati dati per il gioco 352414
# Recuperati dati per il gioco 352418
# Recuperati dati per il gioco 352428
# Recuperati dati per il gioco 352454
# Recuperati dati per il gioco 352482
# Recuperati dati per il gioco 352483
# Recuperati dati per il gioco 352485
# Recuperati dati per il gioco 352551
# Recuperati dati per il gioco 352567
# Recuperati dati per il gioco 352573
# Recuperati dati per il gioco 352574
# Recuperati dati per il gioco 352575
# Recuperati dati per il gioco 352583
# Recuperati dati per il gioco 352586
# Recuperati dati per il gioco 352591
# Recuperati dati per il gioco 352593
# Recuperati dati per il gioco 352596
# Recuperati dati per il gioco 352599
# Recuperati dati per il gioco 352602
# Recuperati dati per il gioco 352605
# Recuperati dati per il gioco 352606
# Recuperati dati per il gioco 352608
# Recuperati dati per il gioco 352610
# Recuperati dati per il gioco 352611
# Recuperati dati per il gioco 352612
# Recuperati dati per il gioco 352616
# Recuperati dati per il gioco 352617
# Recuperati dati per il gioco 352627
# Recuperati dati per il gioco 352628
# Recuperati dati per il gioco 352646
# Recuperati dati per il gioco 352651
# Recuperati dati per il gioco 352652
# Recuperati dati per il gioco 352665
# Recuperati dati per il gioco 352672
# Recuperati dati per il gioco 352681
# Recuperati dati per il gioco 352689
# Recuperati dati per il gioco 352695
# Recuperati dati per il gioco 352697
# Recuperati dati per il gioco 352710
# Recuperati dati per il gioco 352712
# Recuperati dati per il gioco 352713
# Recuperati dati per il gioco 352714
# Recuperati dati per il gioco 352725
# Recuperati dati per il gioco 352735
# Recuperati dati per il gioco 352764
# Recuperati dati per il gioco 352798
# Recuperati dati per il gioco 352818
# Recuperati dati per il gioco 352823
# Recuperati dati per il gioco 352826
# Recuperati dati per il gioco 352828
# Recuperati dati per il gioco 352840
# Recuperati dati per il gioco 352841
# Recuperati dati per il gioco 352860
# Recuperati dati per il gioco 352876
# Recuperati dati per il gioco 352889
# Recuperati dati per il gioco 352890
# Recuperati dati per il gioco 352899
# Recuperati dati per il gioco 352918
# Recuperati dati per il gioco 352979
# Recuperati dati per il gioco 352981
# Recuperati dati per il gioco 352992
# Recuperati dati per il gioco 352993
# Recuperati dati per il gioco 352994
# Recuperati dati per il gioco 352996
# Recuperati dati per il gioco 352998
# Recuperati dati per il gioco 352999
# Recuperati dati per il gioco 353000
# Recuperati dati per il gioco 353003
# Recuperati dati per il gioco 353019
# Recuperati dati per il gioco 353086
# Recuperati dati per il gioco 353130
# Recuperati dati per il gioco 353131
# Recuperati dati per il gioco 353132
# Recuperati dati per il gioco 353139
# Recuperati dati per il gioco 353148
# Recuperati dati per il gioco 353150
# Recuperati dati per il gioco 353152
# Recuperati dati per il gioco 353155
# Recuperati dati per il gioco 353174
# Recuperati dati per il gioco 353175
# Recuperati dati per il gioco 353178
# Recuperati dati per il gioco 353191
# Recuperati dati per il gioco 353193
# Recuperati dati per il gioco 353196
# Recuperati dati per il gioco 353226
# Recuperati dati per il gioco 353288
# Recuperati dati per il gioco 353304
# Recuperati dati per il gioco 353305
# Recuperati dati per il gioco 353311
# Recuperati dati per il gioco 353322
# Recuperati dati per il gioco 353326
# Recuperati dati per il gioco 353380
# Recuperati dati per il gioco 353382
# Recuperati dati per il gioco 353403
# Recuperati dati per il gioco 353411
# Recuperati dati per il gioco 353421
# Recuperati dati per il gioco 353422
# Recuperati dati per il gioco 353456
# Recuperati dati per il gioco 353460
# Recuperati dati per il gioco 353470
# Recuperati dati per il gioco 353508
# Recuperati dati per il gioco 353515
# Recuperati dati per il gioco 353543
# Recuperati dati per il gioco 353544
# Recuperati dati per il gioco 353545
# Recuperati dati per il gioco 353546
# Recuperati dati per il gioco 353548
# Recuperati dati per il gioco 353562
# Recuperati dati per il gioco 353572
# Recuperati dati per il gioco 353575
# Recuperati dati per il gioco 353580
# Recuperati dati per il gioco 353632
# Recuperati dati per il gioco 353636
# Recuperati dati per il gioco 353637
# Recuperati dati per il gioco 353677
# Recuperati dati per il gioco 353681
# Recuperati dati per il gioco 353684
# Recuperati dati per il gioco 353719
# Recuperati dati per il gioco 353734
# Recuperati dati per il gioco 353745
# Recuperati dati per il gioco 353765
# Recuperati dati per il gioco 353779
# Recuperati dati per il gioco 353781
# Recuperati dati per il gioco 353782
# Recuperati dati per il gioco 353794
# Recuperati dati per il gioco 353798
# Recuperati dati per il gioco 353808
# Recuperati dati per il gioco 353812
# Recuperati dati per il gioco 353815
# Recuperati dati per il gioco 353821
# Recuperati dati per il gioco 353822
# Recuperati dati per il gioco 353839
# Recuperati dati per il gioco 353840
# Recuperati dati per il gioco 353841
# Recuperati dati per il gioco 353843
# Recuperati dati per il gioco 353848
# Recuperati dati per il gioco 353851
# Recuperati dati per il gioco 353862
# Recuperati dati per il gioco 353864
# Recuperati dati per il gioco 353865
# Recuperati dati per il gioco 353880
# Recuperati dati per il gioco 353889
# Recuperati dati per il gioco 353890
# Recuperati dati per il gioco 353905
# Recuperati dati per il gioco 353921
# Recuperati dati per il gioco 353928
# Recuperati dati per il gioco 353938
# Recuperati dati per il gioco 353942
# Recuperati dati per il gioco 353945
# Recuperati dati per il gioco 353949
# Recuperati dati per il gioco 353960
# Recuperati dati per il gioco 353977
# Recuperati dati per il gioco 353980
# Recuperati dati per il gioco 354014
# Recuperati dati per il gioco 354022
# Recuperati dati per il gioco 354034
# Recuperati dati per il gioco 354042
# Recuperati dati per il gioco 354051
# Recuperati dati per il gioco 354124
# Recuperati dati per il gioco 354132
# Recuperati dati per il gioco 354138
# Recuperati dati per il gioco 354139
# Recuperati dati per il gioco 354140
# Recuperati dati per il gioco 354142
# Recuperati dati per il gioco 354148
# Recuperati dati per il gioco 354163
# Recuperati dati per il gioco 354201
# Recuperati dati per il gioco 354203
# Recuperati dati per il gioco 354204
# Recuperati dati per il gioco 354205
# Recuperati dati per il gioco 354206
# Recuperati dati per il gioco 354208
# Recuperati dati per il gioco 354213
# Recuperati dati per il gioco 354219
# Recuperati dati per il gioco 354242
# Recuperati dati per il gioco 354248
# Recuperati dati per il gioco 354252
# Recuperati dati per il gioco 354254
# Recuperati dati per il gioco 354255
# Recuperati dati per il gioco 354258
# Recuperati dati per il gioco 354263
# Recuperati dati per il gioco 354264
# Recuperati dati per il gioco 354268
# Recuperati dati per il gioco 354269
# Recuperati dati per il gioco 354270
# Recuperati dati per il gioco 354271
# Recuperati dati per il gioco 354273
# Recuperati dati per il gioco 354275
# Recuperati dati per il gioco 354276
# Recuperati dati per il gioco 354285
# Recuperati dati per il gioco 354286
# Recuperati dati per il gioco 354291
# Recuperati dati per il gioco 354298
# Recuperati dati per il gioco 354299
# Recuperati dati per il gioco 354301
# Recuperati dati per il gioco 354302
# Recuperati dati per il gioco 354303
# Recuperati dati per il gioco 354304
# Recuperati dati per il gioco 354305
# Recuperati dati per il gioco 354307
# Recuperati dati per il gioco 354309
# Recuperati dati per il gioco 354311
# Recuperati dati per il gioco 354312
# Recuperati dati per il gioco 354313
# Recuperati dati per il gioco 354314
# Recuperati dati per il gioco 354316
# Recuperati dati per il gioco 354317
# Recuperati dati per il gioco 354319
# Recuperati dati per il gioco 354320
# Recuperati dati per il gioco 354321
# Recuperati dati per il gioco 354322
# Recuperati dati per il gioco 354323
# Recuperati dati per il gioco 354324
# Recuperati dati per il gioco 354328
# Recuperati dati per il gioco 354331
# Recuperati dati per il gioco 354332
# Recuperati dati per il gioco 354333
# Recuperati dati per il gioco 354335
# Recuperati dati per il gioco 354346
# Recuperati dati per il gioco 354347
# Recuperati dati per il gioco 354349
# Recuperati dati per il gioco 354350
# Recuperati dati per il gioco 354351
# Recuperati dati per il gioco 354357
# Recuperati dati per il gioco 354358
# Recuperati dati per il gioco 354361
# Recuperati dati per il gioco 354364
# Recuperati dati per il gioco 354368
# Recuperati dati per il gioco 354371
# Recuperati dati per il gioco 354372
# Recuperati dati per il gioco 354373
# Recuperati dati per il gioco 354378
# Recuperati dati per il gioco 354381
# Recuperati dati per il gioco 354385
# Recuperati dati per il gioco 354387
# Recuperati dati per il gioco 354388
# Recuperati dati per il gioco 354392
# Recuperati dati per il gioco 354393
# Recuperati dati per il gioco 354395
# Recuperati dati per il gioco 354401
# Recuperati dati per il gioco 354402
# Recuperati dati per il gioco 354404
# Recuperati dati per il gioco 354405
# Recuperati dati per il gioco 354411
# Recuperati dati per il gioco 354412
# Recuperati dati per il gioco 354416
# Recuperati dati per il gioco 354417
# Recuperati dati per il gioco 354419
# Recuperati dati per il gioco 354420
# Recuperati dati per il gioco 354425
# Recuperati dati per il gioco 354427
# Recuperati dati per il gioco 354440
# Recuperati dati per il gioco 354441
# Recuperati dati per il gioco 354442
# Recuperati dati per il gioco 354449
# Recuperati dati per il gioco 354457
# Recuperati dati per il gioco 354459
# Recuperati dati per il gioco 354461
# Recuperati dati per il gioco 354462
# Recuperati dati per il gioco 354463
# Recuperati dati per il gioco 354466
# Recuperati dati per il gioco 354472
# Recuperati dati per il gioco 354478
# Recuperati dati per il gioco 354494
# Recuperati dati per il gioco 354495
# Recuperati dati per il gioco 354498
# Recuperati dati per il gioco 354499
# Recuperati dati per il gioco 354500
# Recuperati dati per il gioco 354507
# Recuperati dati per il gioco 354509
# Recuperati dati per il gioco 354518
# Recuperati dati per il gioco 354537
# Recuperati dati per il gioco 354538
# Recuperati dati per il gioco 354539
# Recuperati dati per il gioco 354540
# Recuperati dati per il gioco 354544
# Recuperati dati per il gioco 354549
# Recuperati dati per il gioco 354563
# Recuperati dati per il gioco 354565
# Recuperati dati per il gioco 354567
# Recuperati dati per il gioco 354568
# Recuperati dati per il gioco 354570
# Recuperati dati per il gioco 354600
# Recuperati dati per il gioco 354604
# Recuperati dati per il gioco 354605
# Recuperati dati per il gioco 354606
# Recuperati dati per il gioco 354607
# Recuperati dati per il gioco 354608
# Recuperati dati per il gioco 354610
# Recuperati dati per il gioco 354611
# Recuperati dati per il gioco 354612
# Recuperati dati per il gioco 354613
# Recuperati dati per il gioco 354614
# Recuperati dati per il gioco 354615
# Recuperati dati per il gioco 354616
# Recuperati dati per il gioco 354617
# Recuperati dati per il gioco 354618
# Recuperati dati per il gioco 354619
# Recuperati dati per il gioco 354622
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 4
#       2 game_ids = range(350186,400000)  # La lista di ID di giochi che vuoi recuperare
#       3 for game_id in game_ids:
# ----> 4     get_data_with_backoff(game_id)
#       6 # Stampa i dati raccolti o esegui altre operazioni
#       7 print(f"Totale giochi recuperati: {len(games_data)}")
#
# Cell In[2], line 8, in get_data_with_backoff(game_id, max_retries)
#       6 for i in range(max_retries):
#       7     try:
# ----> 8         response = requests.get(url)
#       9         response.raise_for_status()
#      10         time.sleep(1)  # Pausa per evitare di sovraccaricare l'API
#
# File ~/.local/lib/python3.12/site-packages/requests/api.py:73, in get(url, params, **kwargs)
#      62 def get(url, params=None, **kwargs):
#      63     r"""Sends a GET request.
#      64
#      65     :param url: URL for the new :class:`Request` object.
#    (...)
#      70     :rtype: requests.Response
#      71     """
# ---> 73     return request("get", url, params=params, **kwargs)
#
# File ~/.local/lib/python3.12/site-packages/requests/api.py:59, in request(method, url, **kwargs)
#      55 # By using the 'with' statement we are sure the session is closed, thus we
#      56 # avoid leaving sockets open which can trigger a ResourceWarning in some
#      57 # cases, and look like a memory leak in others.
#      58 with sessions.Session() as session:
# ---> 59     return session.request(method=method, url=url, **kwargs)
#
# File ~/.local/lib/python3.12/site-packages/requests/sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     584 send_kwargs = {
#     585     "timeout": timeout,
#     586     "allow_redirects": allow_redirects,
#     587 }
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File ~/.local/lib/python3.12/site-packages/requests/sessions.py:703, in Session.send(self, request, **kwargs)
#     700 start = preferred_clock()
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#     706 elapsed = preferred_clock() - start
#
# File ~/.local/lib/python3.12/site-packages/requests/adapters.py:667, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     664     timeout = TimeoutSauce(connect=timeout, read=timeout)
#     666 try:
# --> 667     resp = conn.urlopen(
#     668         method=request.method,
#     669         url=url,
#     670         body=request.body,
#     671         headers=request.headers,
#     672         redirect=False,
#     673         assert_same_host=False,
#     674         preload_content=False,
#     675         decode_content=False,
#     676         retries=self.max_retries,
#     677         timeout=timeout,
#     678         chunked=chunked,
#     679     )
#     681 except (ProtocolError, OSError) as err:
#     682     raise ConnectionError(err, request=request)
#
# File ~/.local/lib/python3.12/site-packages/urllib3/connectionpool.py:789, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     786 response_conn = conn if not release_conn else None
#     788 # Make the request on the HTTPConnection object
# --> 789 response = self._make_request(
#     790     conn,
#     791     method,
#     792     url,
#     793     timeout=timeout_obj,
#     794     body=body,
#     795     headers=headers,
#     796     chunked=chunked,
#     797     retries=retries,
#     798     response_conn=response_conn,
#     799     preload_content=preload_content,
#     800     decode_content=decode_content,
#     801     **response_kw,
#     802 )
#     804 # Everything went great!
#     805 clean_exit = True
#
# File ~/.local/lib/python3.12/site-packages/urllib3/connectionpool.py:536, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     534 # Receive the response from the server
#     535 try:
# --> 536     response = conn.getresponse()
#     537 except (BaseSSLError, OSError) as e:
#     538     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# File ~/.local/lib/python3.12/site-packages/urllib3/connection.py:507, in HTTPConnection.getresponse(self)
#     504 from .response import HTTPResponse
#     506 # Get the response from http.client.HTTPConnection
# --> 507 httplib_response = super().getresponse()
#     509 try:
#     510     assert_header_parsing(httplib_response.msg)
#
# File /usr/local/python/3.12.1/lib/python3.12/http/client.py:1419, in HTTPConnection.getresponse(self)
#    1417 try:
#    1418     try:
# -> 1419         response.begin()
#    1420     except ConnectionError:
#    1421         self.close()
#
# File /usr/local/python/3.12.1/lib/python3.12/http/client.py:331, in HTTPResponse.begin(self)
#     329 # read until we get a non-100 response
#     330 while True:
# --> 331     version, status, reason = self._read_status()
#     332     if status != CONTINUE:
#     333         break
#
# File /usr/local/python/3.12.1/lib/python3.12/http/client.py:292, in HTTPResponse._read_status(self)
#     291 def _read_status(self):
# --> 292     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     293     if len(line) > _MAXLINE:
#     294         raise LineTooLong("status line")
#
# File /usr/local/python/3.12.1/lib/python3.12/socket.py:707, in SocketIO.readinto(self, b)
#     705 while True:
#     706     try:
# --> 707         return self._sock.recv_into(b)
#     708     except timeout:
#     709         self._timeout_occurred = True
#
# File /usr/local/python/3.12.1/lib/python3.12/ssl.py:1253, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1249     if flags != 0:
#    1250         raise ValueError(
#    1251           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1252           self.__class__)
# -> 1253     return self.read(nbytes, buffer)
#    1254 else:
#    1255     return super().recv_into(buffer, nbytes, flags)
#
# File /usr/local/python/3.12.1/lib/python3.12/ssl.py:1105, in SSLSocket.read(self, len, buffer)
#    1103 try:
#    1104     if buffer is not None:
# -> 1105         return self._sslobj.read(len, buffer)
#    1106     else:
#    1107         return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %%
import pandas as pd
# Creazione del DataFrame
games_df = pd.DataFrame(games_data)

# Salva i dati in un file CSV
games_df.to_csv("games_2022b_to_present.csv", index=False)
print("Dati salvati in games_2022_to_present.csv")
# Out:
# Dati salvati in games_2022_to_present.csv
